# %% [markdown]
# # Exploring INPA's Bird Collection Database

# %% [markdown]
# > *written by Nelson Buainain, 2021*

# %% [markdown]
# <img src=https://acta.inpa.gov.br/logo_inpa/COLECOES/PNG/colecoes-recursosgeneticos.png width="300">

# %% [markdown]
# ## Data description

# %% [markdown]
# This database consist of about 28,000 records genetic material of bird that are housed at INPA's scientific collection. These records have been collected in the past decades and, although there was an attempt to standardize the quality and completeness of data, this is mostly not consistent. I extensively reviewed this database correcting and inserting missing data information in the past one year. This process was done mostly manually using Microsoft Excel because of the importance to keep correctness of information of each individual data. Thus, all the ramaining missing data is mostly information that could not be retrieved and could not be inputed. Pandas was used to help visualizing missing data and get a general view of the database.

# %% [markdown]
# ## Purpose

# %% [markdown]
# This is the code I used as part of a data science project to explore the Instituto Nacional de Pesquisas da Amazonia (INPA)'s bird tissue collection.
#
# The goal of this project was to:
#
# * check the quality of the data being input in the database
# * check how much data is missing and what are the most problematic fields
# * infer what are the most and least representative groups, areas, collectors, etc, in the collection
# * provide some basic statistics about the collection
#
#
# This will help to improve future decisions on how to manage information, improve data collecting, optimize financial resources for future expeditions, which taxa to collect and to not collect, etc...

# %% [markdown]
# ## Variables descriptions

# %% [raw]
# * 0   No TEC.             Full tissue number, unique tag number that identifies a sample in the collection
# * 1   numero              Same as previous but without 'INPA A' prefix
# * 2   Sigla prep          Abbreviation of the person who prepared the skin or extracted the blood samples
# * 3   Nº prepa            Number of the person who prepared the skin or extracted the blood samples
# * 4   Nome preparador     Name of the person who prepared the skin or extracted the blood samples
# * 5   Sigla campo         Abbreviation of the field name used for the expedition
# * 6   Nº campo            Unique number used to identify the sample in the field
# * 7   ORDEM               The Order (taxonomic category) that the sample belongs to
# * 8   FAMÍLIA             The Family (taxonomic category) that the sample belongs to
# * 9   GÊNERO              The GENUS (taxonomic category) that the sample belongs to
# * 10  ESPÉCIE             The SPECIFIC EPITHET (taxonomic category) that the sample belongs to
# * 11  GÊNERO ESPÉCIE      The FULL SPECIES name (taxonomic category) that the sample belongs to
# * 12  SEXO                The SEX (taxonomic category) that the sample belongs to, ideally should be Male or Female
# * 13  EXPEDIÇÃO           The expedition during which the samples was collected
# * 14  EST                 The State the samples was collected in
# * 15  LOCALIDADE          The locality (most specific site) the samples was collected in
# * 16  area_endemism       The area of endemism the samples was collected in following Silva 1996
# * 17  LAT G               The degree of Latitude of the locality
# * 18  LAT M               The minute of Latitude of the locality
# * 19  LAT S               The second of Latitude of the locality
# * 20  LAT_N/S             The hemisphere (north or south) of Latitude of the locality
# * 21  LON G               The degree of Longitude of the locality
# * 22  LON M               The minute of Longitude of the locality
# * 23  LON S               The second of Longitude of the locality
# * 24  LON_E/W             The side (west or east) of Longitude of the locality
# * 25  LAT_DEC             The latitude in decimal degree of the sample's locality
# * 26  LON_DEC             The longitude in decimal degree of the sample's locality
# * 27  TEMPO ATÉ CONSERVAR Time until preservation of the samples since collected
# * 28  MÉTODO DE COLETA    Method used to collect samples
# * 29  MÚSCULO             If sample is of type tissue/muscle (X for yes, blank for no)
# * 30  CORAÇÃO             If sample is of type heart (X for yes, blank for no)
# * 31  FÍGADO              If sample is of type liver (X for yes, blank for no)
# * 32  SANGUE              If sample is of blood (X for yes, blank for no)
# * 33  MEIO PRESERV. DEF.  Definitive preservation method
# * 34  DATA COLETA         Date in which the sample was collected
# * 35  DATA PREP.          Date in which the samples was preserved
# * 36  OBSERVAÇÕES         General Observation about the samples which did not fit into any other field
# * 37  EMPRESTADO          If the sample was loaned to someone a first time
# * 38  DATA                Date of first tissue loan
# * 39  GUIA N°             Number of first tissue loan
# * 40  PARA                Person to whom the first tissue loan was conceived
# * 41  Obs                 Additional observations to the first tissue loan
# * 42  EMPRESTADO.1        If the sample was loaned to someone a second time
# * 43  DATA.1              Date of second tissue loan
# * 44  GUIA N°.1           Number of second tissue loan
# * 45  PARA.1              Person to whom the second tissue loan was conceived
# * 46  EMPRESTADO.2        If the sample was loaned to someone a third time
# * 47  DATA.2              Date of third tissue loan
# * 48  GUIA N°.2           Number of third tissue loan
# * 49  PARA.2              Person to whom the third tissue loan was conceived
# * 50  EMPRESTADO.3        If the sample was loaned to someone a third time
# * 51  DATA.3              Date of third tissue loan
# * 52  GUIA N°.3           Number of fourth tissue loan
# * 53  PARA.3              Person to whom the fourth tissue loan was conceived

# %% [markdown]
# ## Importing packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Importing some functions that will be useful along the analses

# %%
# A second function to add percentage over countplot, I will leave this here as backup
# Function to add percentage over bars in count plots
# def bar_percentage(plot, feature):
#     total = len(feature)
#     for p in ax.patches:
#         percentage = '{:.1f}%'.format(100 * p.get_height()/total)
#         x = p.get_x() + p.get_width() / 3.5 - 0.05
#         y = p.get_y() + p.get_height()
#         ax.annotate(percentage, (x, y), size = 12,ha='center', va='bottom')

# %%
#ANOTHER FUNCTION TO ADD PERCENTAGE OVER BAR OR COUNT PLOT
def add_perc(plot, feature):
    total = len(feature)
    for p in ax.patches:
        x=p.get_bbox().get_points()[:,0]
        y=p.get_bbox().get_points()[1,1]
        ax.annotate('{:.1f}%'.format(100.*y/len(feature)), (x.mean(), y), ha='center', va='bottom')

# %% [markdown]
# ## Importing the database

# %%
db = pd.read_csv('database/inpa_bird_collection_database.csv',sep=';',decimal=',')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3169: DtypeWarning: Columns (3,30,31,38,40,42,43,45,46,47,49,50,51,53) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
db.head()
# Out:
#       No TEC.  numero Sigla prep Nº prepa             Nome preparador  \
# 0  INPA A 001       1        MCH    553.0             Mario Cohn-Haft
# 1  INPA A 002       2        LNN      4.0        Luciano Nicolás Naka
# 2  INPA A 003       3        AMF     64.0  Alexandre Mendes Fernandes
# 3  INPA A 004       4        MCH    554.0             Mario Cohn-Haft
# 4  INPA A 005       5        LNN      5.0        Luciano Nicolás Naka
#
#   Sigla campo Nº campo          ORDEM         FAMÍLIA            GÊNERO  \
# 0         NaN      NaN  Passeriformes      Tyrannidae           Elaenia
# 1         NaN      NaN     Piciformes     Capitonidae            Capito
# 2         NaN      NaN  Galbuliformes      Galbulidae  Galbalcyrhynchus
# 3         NaN      NaN  Passeriformes  Thamnophilidae     Hypocnemoides
# 4         NaN      NaN  Passeriformes   Troglodytidae      Pheugopedius
#
#         ESPÉCIE             GÊNERO ESPÉCIE SEXO       EXPEDIÇÃO EST  \
# 0  parvirostris       Elaenia parvirostris    F  Provárzea 2003  AM
# 1    aurovirens          Capito aurovirens    M  Provárzea 2003  AM
# 2      leucotis  Galbalcyrhynchus leucotis    F  Provárzea 2003  AM
# 3   maculicauda  Hypocnemoides maculicauda    M  Provárzea 2003  AM
# 4    genibarbis    Pheugopedius genibarbis    M  Provárzea 2003  AM
#
#                                           LOCALIDADE area_endemism  LAT G  \
# 0  ca 60 km ENE Tabatinga, margem direita Rio Sol...      Inambari    4.0
# 1  ca 60 km ENE Tabatinga, margem direita Rio Sol...      Inambari    4.0
# 2  ca 60 km ENE Tabatinga, margem direita Rio Sol...      Inambari    4.0
# 3  ca 60 km ENE Tabatinga, margem direita Rio Sol...      Inambari    4.0
# 4  Boca rio Jandietuba, ca 12 km E São Paulo de O...      Inambari    3.0
#
#    LAT M  LAT S LAT_N/S  LON G  LON M  LON S LON_E/W  LAT_DEC  LON_DEC  \
# 0    1.0   30.0       S   69.0   27.0   10.0       W   -4.025  -69.453
# 1    1.0   30.0       S   69.0   27.0   10.0       W   -4.025  -69.453
# 2    1.0   30.0       S   69.0   27.0   10.0       W   -4.025  -69.453
# 3    1.0   30.0       S   69.0   27.0   10.0       W   -4.025  -69.453
# 4   27.0   30.0       S   68.0   50.0   40.0       W   -3.458  -68.844
#
#   TEMPO ATÉ CONSERVAR MÉTODO DE COLETA MÚSCULO CORAÇÃO FÍGADO SANGUE  \
# 0                10 h              NaN       X       X      X    NaN
# 1                10 h              NaN       X       X      X    NaN
# 2                10 h              NaN       X       X      X    NaN
# 3                10 h              NaN       X       X      X    NaN
# 4                 3 h              NaN       X       X      X    NaN
#
#    MEIO PRESERV. DEF. DATA COLETA  DATA PREP. OBSERVAÇÕES EMPRESTADO  \
# 0  Nitrogênio líquido  11/09/2003  11/09/2003           _        NaN
# 1  Nitrogênio líquido  11/09/2003  11/09/2003           _        NaN
# 2  Nitrogênio líquido  11/09/2003  11/09/2003           _          X
# 3  Nitrogênio líquido  11/09/2003  11/09/2003       _ im.        NaN
# 4  Nitrogênio líquido  12/09/2003  12/09/2003           _        NaN
#
#          DATA  GUIA N°                  PARA  Obs EMPRESTADO.1 DATA.1  \
# 0         NaN      NaN                   NaN  NaN          NaN    NaN
# 1         NaN      NaN                   NaN  NaN          NaN    NaN
# 2  21/09/2010     59.0  Claydson P. de Assis  NaN          NaN    NaN
# 3         NaN      NaN                   NaN  NaN          NaN    NaN
# 4         NaN      NaN                   NaN  NaN          NaN    NaN
#
#    GUIA N°.1 PARA.1 EMPRESTADO.2 DATA.2  GUIA N°.2 PARA.2 EMPRESTADO.3 DATA.3  \
# 0        NaN    NaN          NaN    NaN        NaN    NaN          NaN    NaN
# 1        NaN    NaN          NaN    NaN        NaN    NaN          NaN    NaN
# 2        NaN    NaN          NaN    NaN        NaN    NaN          NaN    NaN
# 3        NaN    NaN          NaN    NaN        NaN    NaN          NaN    NaN
# 4        NaN    NaN          NaN    NaN        NaN    NaN          NaN    NaN
#
#    GUIA N°.3 PARA.3
# 0        NaN    NaN
# 1        NaN    NaN
# 2        NaN    NaN
# 3        NaN    NaN
# 4        NaN    NaN

# %% [markdown]
# ## Getting to know our data base

# %% [markdown]
# > We will take a look at the general information of our dataset to start to get know it

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28734 entries, 0 to 28733
# Data columns (total 54 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   No TEC.              28734 non-null  object
#  1   numero               28734 non-null  int64
#  2   Sigla prep           14831 non-null  object
#  3   Nº prepa             13162 non-null  object
#  4   Nome preparador      25331 non-null  object
#  5   Sigla campo          16278 non-null  object
#  6   Nº campo             16291 non-null  object
#  7   ORDEM                26483 non-null  object
#  8   FAMÍLIA              26483 non-null  object
#  9   GÊNERO               26490 non-null  object
#  10  ESPÉCIE              26263 non-null  object
#  11  GÊNERO ESPÉCIE       26490 non-null  object
#  12  SEXO                 18363 non-null  object
#  13  EXPEDIÇÃO            19687 non-null  object
#  14  EST                  26368 non-null  object
#  15  LOCALIDADE           26421 non-null  object
#  16  area_endemism        25894 non-null  object
#  17  LAT G                26212 non-null  float64
#  18  LAT M                26211 non-null  float64
#  19  LAT S                17567 non-null  float64
#  20  LAT_N/S              26212 non-null  object
#  21  LON G                26212 non-null  float64
#  22  LON M                26210 non-null  float64
#  23  LON S                17544 non-null  float64
#  24  LON_E/W              26212 non-null  object
#  25  LAT_DEC              26212 non-null  float64
#  26  LON_DEC              26212 non-null  float64
#  27  TEMPO ATÉ CONSERVAR  5953 non-null   object
#  28  MÉTODO DE COLETA     21706 non-null  object
#  29  MÚSCULO              12913 non-null  object
#  30  CORAÇÃO              2741 non-null   object
#  31  FÍGADO               2669 non-null   object
#  32  SANGUE               13398 non-null  object
#  33  MEIO PRESERV. DEF.   24266 non-null  object
#  34  DATA COLETA          26300 non-null  object
#  35  DATA PREP.           14780 non-null  object
#  36  OBSERVAÇÕES          8396 non-null   object
#  37  EMPRESTADO           1498 non-null   object
#  38  DATA                 1202 non-null   object
#  39  GUIA N°              1202 non-null   float64
#  40  PARA                 1202 non-null   object
#  41  Obs                  53 non-null     object
#  42  EMPRESTADO.1         165 non-null    object
#  43  DATA.1               165 non-null    object
#  44  GUIA N°.1            165 non-null    float64
#  45  PARA.1               165 non-null    object
#  46  EMPRESTADO.2         39 non-null     object
#  47  DATA.2               39 non-null     object
#  48  GUIA N°.2            39 non-null     float64
#  49  PARA.2               39 non-null     object
#  50  EMPRESTADO.3         2 non-null      object
#  51  DATA.3               2 non-null      object
#  52  GUIA N°.3            2 non-null      float64
#  53  PARA.3               2 non-null      object
# dtypes: float64(12), int64(1), object(41)
# memory usage: 11.8+ MB

# %%
db.columns
# Out:
# Index(['No TEC.', 'numero', 'Sigla prep', 'Nº prepa', 'Nome preparador',
#        'Sigla campo', 'Nº campo', 'ORDEM', 'FAMÍLIA', 'GÊNERO', 'ESPÉCIE',
#        'GÊNERO ESPÉCIE', 'SEXO', 'EXPEDIÇÃO', 'EST', 'LOCALIDADE',
#        'area_endemism', 'LAT G', 'LAT M', 'LAT S', 'LAT_N/S', 'LON G', 'LON M',
#        'LON S', 'LON_E/W', 'LAT_DEC', 'LON_DEC', 'TEMPO ATÉ CONSERVAR',
#        'MÉTODO DE COLETA', 'MÚSCULO', 'CORAÇÃO', 'FÍGADO', 'SANGUE',
#        'MEIO PRESERV. DEF.', 'DATA COLETA', 'DATA PREP.', 'OBSERVAÇÕES',
#        'EMPRESTADO', 'DATA', 'GUIA N°', 'PARA', 'Obs', 'EMPRESTADO.1',
#        'DATA.1', 'GUIA N°.1', 'PARA.1', 'EMPRESTADO.2', 'DATA.2', 'GUIA N°.2',
#        'PARA.2', 'EMPRESTADO.3', 'DATA.3', 'GUIA N°.3', 'PARA.3'],
#       dtype='object')

# %% [markdown]
# ** We will select only the columns that may potentially will give us some interesting information **

# %%
data = db[['No TEC.', 'Nome preparador','ORDEM', 'FAMÍLIA', 'GÊNERO', 'ESPÉCIE', 'GÊNERO ESPÉCIE',
       'SEXO', 'EST', 'LOCALIDADE','area_endemism', 'LAT_DEC', 'LON_DEC',
       'TEMPO ATÉ CONSERVAR', 'MÉTODO DE COLETA', 'MÚSCULO', 'CORAÇÃO',
       'FÍGADO', 'SANGUE', 'MEIO PRESERV. DEF.', 'DATA COLETA', 'DATA PREP.',
'EMPRESTADO', 'DATA', 'GUIA N°', 'PARA', 'Obs', 'EMPRESTADO.1',
       'DATA.1', 'GUIA N°.1', 'PARA.1', 'EMPRESTADO.2', 'DATA.2', 'GUIA N°.2',
       'PARA.2', 'EMPRESTADO.3', 'DATA.3', 'GUIA N°.3', 'PARA.3']]

# %%
data.head()
# Out:
#       No TEC.             Nome preparador          ORDEM         FAMÍLIA  \
# 0  INPA A 001             Mario Cohn-Haft  Passeriformes      Tyrannidae
# 1  INPA A 002        Luciano Nicolás Naka     Piciformes     Capitonidae
# 2  INPA A 003  Alexandre Mendes Fernandes  Galbuliformes      Galbulidae
# 3  INPA A 004             Mario Cohn-Haft  Passeriformes  Thamnophilidae
# 4  INPA A 005        Luciano Nicolás Naka  Passeriformes   Troglodytidae
#
#              GÊNERO       ESPÉCIE             GÊNERO ESPÉCIE SEXO EST  \
# 0           Elaenia  parvirostris       Elaenia parvirostris    F  AM
# 1            Capito    aurovirens          Capito aurovirens    M  AM
# 2  Galbalcyrhynchus      leucotis  Galbalcyrhynchus leucotis    F  AM
# 3     Hypocnemoides   maculicauda  Hypocnemoides maculicauda    M  AM
# 4      Pheugopedius    genibarbis    Pheugopedius genibarbis    M  AM
#
#                                           LOCALIDADE area_endemism  LAT_DEC  \
# 0  ca 60 km ENE Tabatinga, margem direita Rio Sol...      Inambari   -4.025
# 1  ca 60 km ENE Tabatinga, margem direita Rio Sol...      Inambari   -4.025
# 2  ca 60 km ENE Tabatinga, margem direita Rio Sol...      Inambari   -4.025
# 3  ca 60 km ENE Tabatinga, margem direita Rio Sol...      Inambari   -4.025
# 4  Boca rio Jandietuba, ca 12 km E São Paulo de O...      Inambari   -3.458
#
#    LON_DEC TEMPO ATÉ CONSERVAR MÉTODO DE COLETA MÚSCULO CORAÇÃO FÍGADO SANGUE  \
# 0  -69.453                10 h              NaN       X       X      X    NaN
# 1  -69.453                10 h              NaN       X       X      X    NaN
# 2  -69.453                10 h              NaN       X       X      X    NaN
# 3  -69.453                10 h              NaN       X       X      X    NaN
# 4  -68.844                 3 h              NaN       X       X      X    NaN
#
#    MEIO PRESERV. DEF. DATA COLETA  DATA PREP. EMPRESTADO        DATA  GUIA N°  \
# 0  Nitrogênio líquido  11/09/2003  11/09/2003        NaN         NaN      NaN
# 1  Nitrogênio líquido  11/09/2003  11/09/2003        NaN         NaN      NaN
# 2  Nitrogênio líquido  11/09/2003  11/09/2003          X  21/09/2010     59.0
# 3  Nitrogênio líquido  11/09/2003  11/09/2003        NaN         NaN      NaN
# 4  Nitrogênio líquido  12/09/2003  12/09/2003        NaN         NaN      NaN
#
#                    PARA  Obs EMPRESTADO.1 DATA.1  GUIA N°.1 PARA.1  \
# 0                   NaN  NaN          NaN    NaN        NaN    NaN
# 1                   NaN  NaN          NaN    NaN        NaN    NaN
# 2  Claydson P. de Assis  NaN          NaN    NaN        NaN    NaN
# 3                   NaN  NaN          NaN    NaN        NaN    NaN
# 4                   NaN  NaN          NaN    NaN        NaN    NaN
#
#   EMPRESTADO.2 DATA.2  GUIA N°.2 PARA.2 EMPRESTADO.3 DATA.3  GUIA N°.3 PARA.3
# 0          NaN    NaN        NaN    NaN          NaN    NaN        NaN    NaN
# 1          NaN    NaN        NaN    NaN          NaN    NaN        NaN    NaN
# 2          NaN    NaN        NaN    NaN          NaN    NaN        NaN    NaN
# 3          NaN    NaN        NaN    NaN          NaN    NaN        NaN    NaN
# 4          NaN    NaN        NaN    NaN          NaN    NaN        NaN    NaN

# %% [markdown]
# ** Record without genus/species identification and locality are likely to be errors, reserved spots in the database or simply undesirable for our purpose to I will exclude them to see some general count numbers **

# %%
data[(~data['GÊNERO'].isnull()) & (~data['LOCALIDADE'].isnull())].count()
# Out:
# No TEC.                26136
# Nome preparador        24927
# ORDEM                  26130
# FAMÍLIA                26130
# GÊNERO                 26136
# ESPÉCIE                25913
# GÊNERO ESPÉCIE         26136
# SEXO                   18050
# EST                    26037
# LOCALIDADE             26136
# area_endemism           9458
# LAT_DEC                 9674
# LON_DEC                 9674
# TEMPO ATÉ CONSERVAR     3304
# MÉTODO DE COLETA        7240
# MÚSCULO                 4579
# CORAÇÃO                 1323
# FÍGADO                  1265
# SANGUE                  5058
# MEIO PRESERV. DEF.      8655
# DATA COLETA             9754
# DATA PREP.              5165
# EMPRESTADO               960
# DATA                     691
# GUIA N°                  691
# PARA                     691
# Obs                        2
# EMPRESTADO.1              91
# DATA.1                    91
# GUIA N°.1                 91
# PARA.1                    91
# EMPRESTADO.2              24
# DATA.2                    24
# GUIA N°.2                 24
# PARA.2                    24
# EMPRESTADO.3               2
# DATA.3                     2
# GUIA N°.3                  2
# PARA.3                     2
# dtype: int64

# %% [markdown]
# ** For further analyses I will admit records with no locality but record with no identification at least at the genus level are usually problematic and less informative so I will exclude them to produce some of the basic information **

# %%
data_clean = data.dropna(subset=['GÊNERO'])

# %%
data_clean.count()
# Out:
# No TEC.                26490
# Nome preparador        25281
# ORDEM                  26483
# FAMÍLIA                26483
# GÊNERO                 26490
# ESPÉCIE                26263
# GÊNERO ESPÉCIE         26490
# SEXO                   18337
# EST                    26328
# LOCALIDADE             26374
# area_endemism          25857
# LAT_DEC                26175
# LON_DEC                26175
# TEMPO ATÉ CONSERVAR     5944
# MÉTODO DE COLETA       21674
# MÚSCULO                12871
# CORAÇÃO                 2723
# FÍGADO                  2651
# SANGUE                 13390
# MEIO PRESERV. DEF.     24217
# DATA COLETA            26263
# DATA PREP.             14742
# EMPRESTADO              1498
# DATA                    1202
# GUIA N°                 1202
# PARA                    1202
# Obs                        3
# EMPRESTADO.1             165
# DATA.1                   165
# GUIA N°.1                165
# PARA.1                   165
# EMPRESTADO.2              39
# DATA.2                    39
# GUIA N°.2                 39
# PARA.2                    39
# EMPRESTADO.3               2
# DATA.3                     2
# GUIA N°.3                  2
# PARA.3                     2
# dtype: int64

# %% [markdown]
# ** Let's see what are the field with more missing data **

# %%
plt.figure(figsize=(16, 6))
sns.heatmap(data_clean.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# **We can see that the most problematic fields are: 'Nome do preparador', 'sexo', 'tempo até conservar', 'metodo de coleta', 'data preparacao'. The remaining fields are not necessarily missing data and might not just be applicable for that record**
#
# Let's take a look at these samples

# %%
data_clean['Nome preparador'].isnull().sum()
# Out:
# 1209

# %%
pd.set_option("display.max_columns", None)
data_clean[data_clean['Nome preparador'].isna() == True]
# Out:
#             No TEC. Nome preparador          ORDEM      FAMÍLIA  \
# 6609    INPA A 6615             NaN  Passeriformes   Tyrannidae
# 6610    INPA A 6616             NaN  Passeriformes   Tyrannidae
# 6611    INPA A 6617             NaN  Passeriformes   Tyrannidae
# 6638    INPA A 6644             NaN  Passeriformes   Tyrannidae
# 6639    INPA A 6645             NaN  Passeriformes   Tyrannidae
# ...             ...             ...            ...          ...
# 27753  INPA A 27759             NaN  Passeriformes     Pipridae
# 27754  INPA A 27760             NaN  Passeriformes     Pipridae
# 27755  INPA A 27761             NaN  Passeriformes  Furnariidae
# 27756  INPA A 27762             NaN     Gruiformes     Rallidae
# 27757  INPA A 27763             NaN     Gruiformes     Rallidae
#
#                GÊNERO       ESPÉCIE               GÊNERO ESPÉCIE SEXO EST  \
# 6609          Elaenia      cristata             Elaenia cristata  NaN  RR
# 6610          Elaenia      cristata             Elaenia cristata  NaN  RR
# 6611          Elaenia      cristata             Elaenia cristata  NaN  RR
# 6638          Elaenia      ruficeps             Elaenia ruficeps  NaN  RR
# 6639          Elaenia      cristata             Elaenia cristata  NaN  RR
# ...               ...           ...                          ...  ...  ..
# 27753  Machaeropterus  pyrocephalus  Machaeropterus pyrocephalus    M  AC
# 27754           Pipra   fasciicauda            Pipra fasciicauda    F  AC
# 27755       Automolus   ochrolaemus        Automolus ochrolaemus    F  AC
# 27756    Amaurolimnas      concolor        Amaurolimnas concolor    F  AC
# 27757    Amaurolimnas      concolor        Amaurolimnas concolor    M  AC
#
#                                               LOCALIDADE  LAT_DEC  LON_DEC  \
# 6609   Parque Nacional do Viruá; Estrada Perdida, km ...    1.413  -60.989
# 6610   Parque Nacional do Viruá; Estrada Perdida, km ...    1.413  -60.989
# 6611   Parque Nacional do Viruá; Estrada Perdida, km ...    1.413  -60.989
# 6638   Parque Nacional do Viruá; Estrada Perdida, km ...    1.413  -60.989
# 6639   Parque Nacional do Viruá; Estrada Perdida, km ...    1.413  -60.989
# ...                                                  ...      ...      ...
# 27753  PARNÁ Serra do Divisor, margem direita do rio ...   -7.053  -73.622
# 27754  PARNÁ Serra do Divisor, margem direita do rio ...   -7.053  -73.622
# 27755  PARNÁ Serra do Divisor, margem direita do rio ...   -7.053  -73.622
# 27756  PARNÁ Serra do Divisor, margem direita do rio ...   -7.053  -73.622
# 27757  PARNÁ Serra do Divisor, margem direita do rio ...   -7.053  -73.622
#
#       TEMPO ATÉ CONSERVAR  MÉTODO DE COLETA MÚSCULO CORAÇÃO FÍGADO SANGUE  \
# 6609                  NaN  Rede de neblina      NaN     NaN    NaN      X
# 6610                  NaN  Rede de neblina      NaN     NaN    NaN      X
# 6611                  NaN  Rede de neblina      NaN     NaN    NaN      X
# 6638    7 h até geladeira  Rede de neblina      NaN     NaN    NaN      X
# 6639                  NaN  Rede de neblina      NaN     NaN    NaN      X
# ...                   ...               ...     ...     ...    ...    ...
# 27753        Menor que 6h  Rede de neblina        X     NaN    NaN    NaN
# 27754        Menor que 6h  Rede de neblina        X     NaN    NaN    NaN
# 27755        Menor que 6h  Rede de neblina        X     NaN    NaN    NaN
# 27756        Menor que 6h  Rede de neblina        X     NaN    NaN    NaN
# 27757        Menor que 6h  Rede de neblina        X     NaN    NaN    NaN
#
#       MEIO PRESERV. DEF. DATA COLETA  DATA PREP. EMPRESTADO DATA PARA  \
# 6609              Álcool  2012-05-22  2012-05-22        NaN  NaN  NaN
# 6610              Álcool  2012-05-22  2012-05-22        NaN  NaN  NaN
# 6611              Álcool  2012-05-22  2012-05-22        NaN  NaN  NaN
# 6638              Álcool  2012-05-23  2012-05-23        NaN  NaN  NaN
# 6639              Álcool  2012-05-23  2012-05-23        NaN  NaN  NaN
# ...                  ...         ...         ...        ...  ...  ...
# 27753        Álcool 100%  2019-12-06  2019-12-06        NaN  NaN  NaN
# 27754        Álcool 100%  2019-12-06  2019-12-06        NaN  NaN  NaN
# 27755        Álcool 100%  2019-12-06  2019-12-06        NaN  NaN  NaN
# 27756        Álcool 100%  2019-12-06  2019-12-06        NaN  NaN  NaN
# 27757        Álcool 100%  2019-12-06  2019-12-06        NaN  NaN  NaN
#
#       EMPRESTADO.1 DATA.1 PARA.1 EMPRESTADO.2 DATA.2 PARA.2 EMPRESTADO.3  \
# 6609           NaN    NaN    NaN          NaN    NaN    NaN          NaN
# 6610           NaN    NaN    NaN          NaN    NaN    NaN          NaN
# 6611           NaN    NaN    NaN          NaN    NaN    NaN          NaN
# 6638           NaN    NaN    NaN          NaN    NaN    NaN          NaN
# 6639           NaN    NaN    NaN          NaN    NaN    NaN          NaN
# ...            ...    ...    ...          ...    ...    ...          ...
# 27753          NaN    NaN    NaN          NaN    NaN    NaN          NaN
# 27754          NaN    NaN    NaN          NaN    NaN    NaN          NaN
# 27755          NaN    NaN    NaN          NaN    NaN    NaN          NaN
# 27756          NaN    NaN    NaN          NaN    NaN    NaN          NaN
# 27757          NaN    NaN    NaN          NaN    NaN    NaN          NaN
#
#       DATA.3 PARA.3
# 6609     NaN    NaN
# 6610     NaN    NaN
# 6611     NaN    NaN
# 6638     NaN    NaN
# 6639     NaN    NaN
# ...      ...    ...
# 27753    NaN    NaN
# 27754    NaN    NaN
# 27755    NaN    NaN
# 27756    NaN    NaN
# 27757    NaN    NaN
#
# [1209 rows x 33 columns]

# %%
data_clean['SEXO'].isnull().sum()
# Out:
# 8153

# %%
data_clean['SEXO'].value_counts()
# Out:
# M        9458
# F        6336
# I        2463
# I (M)      42
# MJ         10
# F?          9
# (M)         4
# M?          3
# F           2
# M           2
# F (M)       2
# FJ          1
# F (?)       1
#             1
# I           1
# ? F         1
# M/F?        1
# Name: SEXO, dtype: int64

# %% [markdown]
# ** Sex needs to be taken more seriously... This is a mess **

# %%
data_clean[data_clean['MÉTODO DE COLETA'].isna() == True].sample(20)
# Out:
#             No TEC.                             Nome preparador  \
# 13629  INPA A 13635                             Mateus Ferreira
# 21337  INPA A 21343                         Marco Aurélio Silva
# 35       INPA A 036                  Alexandre Mendes Fernandes
# 23077  INPA A 23083              Mônica S Ribas/Roberta L. Boss
# 21765  INPA A 21771                     Jaqueline Rizzi Fortuna
# 13690  INPA A 13696                             Mateus Ferreira
# 20676  INPA A 20682                      Gisiane Rodrigues Lima
# 5158    INPA A 5164  Camila Ribas, Fernando Horta, Renato Gaban
# 20049  INPA A 20055                                         NaN
# 17350  INPA A 17356                 Carolina Schuch de Oliveira
# 22382  INPA A 22388              Mônica S Ribas/Roberta L. Boss
# 5378    INPA A 5384  Camila Ribas, Fernando Horta, Renato Gaban
# 17464  INPA A 17470                 Carolina Schuch de Oliveira
# 6084    INPA A 6090                                 Jared Wolfe
# 17494  INPA A 17500                 Carolina Schuch de Oliveira
# 22969  INPA A 22975              Mônica S Ribas/Roberta L. Boss
# 14061  INPA A 14067                             Mateus Ferreira
# 14003  INPA A 14009                             Mateus Ferreira
# 21654  INPA A 21660                     Jaqueline Rizzi Fortuna
# 13715  INPA A 13721                             Mateus Ferreira
#
#                 ORDEM           FAMÍLIA          GÊNERO        ESPÉCIE  \
# 13629   Passeriformes   Rhynchocyclidae    Lophotriccus       galeatus
# 21337   Passeriformes  Dendrocolaptidae    Dendrocincla     fuliginosa
# 35      Passeriformes     Troglodytidae    Pheugopedius     genibarbis
# 23077   Passeriformes    Thamnophilidae   Rhegmatorhina   melanosticta
# 21765   Falconiformes        Falconidae       Micrastur    gilvicollis
# 13690   Passeriformes    Thamnophilidae  Epinecrophylla    haematonota
# 20676  Cathartiformes       Cathartidae        Coragyps        atratus
# 5158    Passeriformes          Pipridae     Ceratopipra   rubrocapilla
# 20049   Passeriformes    Thamnophilidae      Hylophylax        naevius
# 17350   Passeriformes  Dendrocolaptidae   Xiphorhynchus     pardalotus
# 22382   Passeriformes    Thamnophilidae     Myrmelastes     rufifacies
# 5378    Passeriformes  Dendrocolaptidae    Dendrocincla     fuliginosa
# 17464   Passeriformes  Dendrocolaptidae   Glyphorynchus       spirurus
# 6084    Passeriformes    Thamnophilidae          Pithys      albifrons
# 17494   Passeriformes  Dendrocolaptidae    Certhiasomus   stictolaemus
# 22969   Passeriformes          Pipridae     Lepidothrix      nattereri
# 14061     Apodiformes       Trochilidae     Phaethornis  superciliosus
# 14003   Passeriformes    Thamnophilidae    Myrmotherula    longipennis
# 21654   Passeriformes          Pipridae     Lepidothrix         serena
# 13690   -0.150  -66.800                 NaN              NaN       X     NaN
# 20676      NaN      NaN                 NaN              NaN       X     NaN
# 5158    -3.705  -55.592                 NaN              NaN       X     NaN
# 20049    1.600  -61.900                 NaN              NaN     NaN     NaN
# 17350   -2.388  -59.900                   0              NaN     NaN     NaN
# 22382   -9.334  -64.708                 NaN              NaN     NaN     NaN
# 5378    -2.546  -55.302                 NaN              NaN       X     NaN
# 17464   -2.388  -59.898                   0              NaN     NaN     NaN
# 6084    -2.342  -60.095                 NaN              NaN     NaN     NaN
# 17494   -2.396  -59.898                   0              NaN     NaN     NaN
# 22969   -9.349  -64.695                 NaN              NaN     NaN     NaN
# 14061   -0.300  -66.817                 NaN              NaN       X     NaN
# 14003   -0.233  -66.850                 NaN              NaN       X     NaN
# 21654   -2.345  -60.095                 NaN              NaN     NaN     NaN
# 13715   -0.150  -66.800                 NaN              NaN       X     NaN
#
#       FÍGADO SANGUE   MEIO PRESERV. DEF. DATA COLETA  DATA PREP. EMPRESTADO  \
# 13629    NaN    NaN               Álcool  17/08/2013         NaN        NaN
# 21337    NaN      X                  NaN  20/08/2011         NaN        NaN
# 35         X    NaN                  NaN  21/09/2003  24/09/2003        NaN
# 23077    NaN      X                  NaN  08/06/2011         NaN        NaN
# 21765    NaN      X                  NaN  19/10/2010         NaN        NaN
# 13690    NaN    NaN               Álcool  19/08/2013         NaN        NaN
# 20676    NaN    NaN          Álcool 100%  12/08/2015  13/01/2017        NaN
# 5158     NaN    NaN               Álcool  05/12/2003         NaN        NaN
# 20049    NaN      X                  NaN  23/01/2016         NaN        NaN
# 17350    NaN      X  Longmire's solution  28/06/2014  28/06/2014        NaN
# 22382    NaN      X                  NaN  31/07/2010         NaN        NaN
# 5378     NaN    NaN               Álcool  15/12/2003         NaN        NaN
# 17464    NaN      X  Longmire's solution  24/07/2014  24/07/2014        NaN
# 6084     NaN      X         Lysis buffer  15/07/2011         NaN        NaN
# 17494    NaN      X  Longmire's solution  27/07/2014  27/07/2014        NaN
# 22969    NaN      X                  NaN  03/06/2011         NaN        NaN
# 14061    NaN    NaN               Álcool  02/09/2013         NaN        NaN
# 14003    NaN    NaN               Álcool  31/08/2013         NaN        NaN
# 21654    NaN      X                  NaN  27/06/2009         NaN        NaN
# 13715    NaN    NaN               Álcool  20/08/2013         NaN        NaN
#
#       DATA  GUIA N° PARA  Obs EMPRESTADO.1 DATA.1  GUIA N°.1 PARA.1  \
# 13629  NaN      NaN  NaN  NaN          NaN    NaN        NaN    NaN
# 21337  NaN      NaN  NaN  NaN          NaN    NaN        NaN    NaN
# 35     NaN      NaN  NaN  NaN          NaN    NaN        NaN    NaN
# 23077  NaN      NaN  NaN  NaN          NaN    NaN        NaN    NaN
# 21765  NaN      NaN  NaN  NaN          NaN    NaN        NaN    NaN
# 13690  NaN      NaN  NaN  NaN          NaN    NaN        NaN    NaN
# 20676  NaN      NaN  NaN  NaN          NaN    NaN        NaN    NaN
# 5158   NaN      NaN  NaN  NaN          NaN    NaN        NaN    NaN
# 20049  NaN      NaN  NaN  NaN          NaN    NaN        NaN    NaN
# 17350  NaN      NaN  NaN  NaN          NaN    NaN        NaN    NaN
# 22382  NaN      NaN  NaN  NaN          NaN    NaN        NaN    NaN
# 5378   NaN      NaN  NaN  NaN          NaN    NaN        NaN    NaN
# 17464  NaN      NaN  NaN  NaN          NaN    NaN        NaN    NaN
# 6084   NaN      NaN  NaN  NaN          NaN    NaN        NaN    NaN
# 17494  NaN      NaN  NaN  NaN          NaN    NaN        NaN    NaN
# 22969  NaN      NaN  NaN  NaN          NaN    NaN        NaN    NaN
# 14061  NaN      NaN  NaN  NaN          NaN    NaN        NaN    NaN
# 14003  NaN      NaN  NaN  NaN          NaN    NaN        NaN    NaN
# 21654  NaN      NaN  NaN  NaN          NaN    NaN        NaN    NaN
# 13715  NaN      NaN  NaN  NaN          NaN    NaN        NaN    NaN
#
#       EMPRESTADO.2 DATA.2  GUIA N°.2 PARA.2 EMPRESTADO.3 DATA.3  GUIA N°.3  \
# 13629          NaN    NaN        NaN    NaN          NaN    NaN        NaN
# 21337          NaN    NaN        NaN    NaN          NaN    NaN        NaN
# 35             NaN    NaN        NaN    NaN          NaN    NaN        NaN
# 23077          NaN    NaN        NaN    NaN          NaN    NaN        NaN
# 21765          NaN    NaN        NaN    NaN          NaN    NaN        NaN
# 13690          NaN    NaN        NaN    NaN          NaN    NaN        NaN
# 20676          NaN    NaN        NaN    NaN          NaN    NaN        NaN
# 5158           NaN    NaN        NaN    NaN          NaN    NaN        NaN
# 20049          NaN    NaN        NaN    NaN          NaN    NaN        NaN
# 17350          NaN    NaN        NaN    NaN          NaN    NaN        NaN
# 22382          NaN    NaN        NaN    NaN          NaN    NaN        NaN
# 5378           NaN    NaN        NaN    NaN          NaN    NaN        NaN
# 17464          NaN    NaN        NaN    NaN          NaN    NaN        NaN
# 6084           NaN    NaN        NaN    NaN          NaN    NaN        NaN
# 17494          NaN    NaN        NaN    NaN          NaN    NaN        NaN
# 22969          NaN    NaN        NaN    NaN          NaN    NaN        NaN
# 14061          NaN    NaN        NaN    NaN          NaN    NaN        NaN
# 14003          NaN    NaN        NaN    NaN          NaN    NaN        NaN
# 21654          NaN    NaN        NaN    NaN          NaN    NaN        NaN
# 13715          NaN    NaN        NaN    NaN          NaN    NaN        NaN
#
#       PARA.3
# 13629    NaN
# 21337    NaN
# 35       NaN
# 23077    NaN
# 21765    NaN
# 13690    NaN
# 20676    NaN
# 5158     NaN
# 20049    NaN
# 17350    NaN
# 22382    NaN
# 5378     NaN
# 17464    NaN
# 6084     NaN
# 17494    NaN
# 22969    NaN
# 14061    NaN
# 14003    NaN
# 21654    NaN
# 13715    NaN

# %%
data_clean['MÉTODO DE COLETA'].isnull().sum()
# Out:
# 4816

# %%
len(data_clean[(data_clean['MÉTODO DE COLETA'].isnull()) & (data_clean['SANGUE'] == 'X')])
# Out:
# 2783

# %%
print(f'Perentage of missing data that are blood samples: {2783/4816*100}')
# Out:
# Perentage of missing data that are blood samples: 57.78654485049833

# %%
data_clean[(data_clean['MÉTODO DE COLETA'].isnull()) & (data_clean['SANGUE'] == 'X')].sample(10)
# Out:
#             No TEC.                 Nome preparador           ORDEM  \
# 6202    INPA A 6208                     Jared Wolfe   Passeriformes
# 21420  INPA A 21426             Marco Aurélio Silva   Passeriformes
# 23330  INPA A 23336               Mariana Tolentino   Passeriformes
# 6028    INPA A 6034                     Jared Wolfe   Passeriformes
# 23126  INPA A 23132  Mônica S Ribas/Roberta L. Boss   Passeriformes
# 21512  INPA A 21518             Marco Aurélio Silva   Passeriformes
# 6010    INPA A 6016                     Jared Wolfe   Passeriformes
# 22773  INPA A 22779  Mônica S Ribas/Roberta L. Boss   Passeriformes
# 21087  INPA A 21093      Fábio Nunes e Ileyne Lopes  Psittaciformes
# 22398  INPA A 22404  Mônica S Ribas/Roberta L. Boss   Passeriformes
#
#                 FAMÍLIA         GÊNERO       ESPÉCIE  \
# 6202    Rhynchocyclidae     Corythopis     torquatus
# 21420          Turdidae         Turdus    albicollis
# 23330          Pipridae       Corapipo    gutturalis
# 6028   Dendrocolaptidae  Glyphorynchus      spirurus
# 23126    Thamnophilidae  Rhegmatorhina    hoffmannsi
# 21512    Thamnophilidae        Isleria       guttata
# 6010   Dendrocolaptidae  Glyphorynchus      spirurus
# 22773    Thamnophilidae   Myrmotherula     axillaris
# 21087       Psittacidae       Pyrrhura  griseipectus
# 22398    Thamnophilidae    Thamnomanes    saturninus
#
#                  GÊNERO ESPÉCIE SEXO EST  \
# 6202       Corythopis torquatus  NaN  AM
# 21420         Turdus albicollis  NaN  AM
# 23330       Corapipo gutturalis    M  AM
# 6028     Glyphorynchus spirurus  NaN  AM
# 23126  Rhegmatorhina hoffmannsi    F  RO
# 21512           Isleria guttata    F  AM
# 6010     Glyphorynchus spirurus  NaN  AM
# 22773    Myrmotherula axillaris    M  RO
# 21087     Pyrrhura griseipectus    F  CE
# 22398    Thamnomanes saturninus    M  RO
#
#                                               LOCALIDADE area_endemism  \
# 6202   Fragmentos PDBFF, BR-174 80 km NE Manaus, Flor...        Guiana
# 21420  Presidente Figueiredo, Lago UHE Balbina, Loren...        Guiana
# 23330  Rio Preto da Eva, BR 174 ca 60 km N de Manaus,...        Guiana
# 6028   Fragmentos PDBFF, BR-174 80 km NE Manaus, Port...        Guiana
# 23126  Porto Velho; margem direita do Rio Madeira; Mó...      Rondonia
# 21512  Presidente Figueiredo, Lago UHE Balbina, Loren...        Guiana
# 6010   Fragmentos PDBFF, BR-174 80 km NE Manaus, km 4...        Guiana
# 22773  Porto Velho; margem esquerda do Rio Madeira; M...      Inambari
# 21087  Ceará, Serra do Baturité, Sítio Floresta, Caix...           NaN
# 22398  Porto Velho, margem direita do Rio Madeira; Mó...      Rondonia
#
#        LAT_DEC  LON_DEC TEMPO ATÉ CONSERVAR MÉTODO DE COLETA MÚSCULO CORAÇÃO  \
# 6202    -2.390  -59.854                 NaN              NaN     NaN     NaN
# 21420   -1.612  -59.635                 NaN              NaN     NaN     NaN
# 23330   -2.366  -59.973                 NaN              NaN     NaN     NaN
# 6028    -2.374  -59.966                 NaN              NaN     NaN     NaN
# 23126   -9.451  -64.392                 NaN              NaN     NaN     NaN
# 21512   -1.668  -59.709                 NaN              NaN     NaN     NaN
# 6010    -2.374  -59.965                 NaN              NaN     NaN     NaN
# 22773   -9.287  -64.744                 NaN              NaN     NaN     NaN
# 21087   -4.207  -38.954                 NaN              NaN     NaN     NaN
# 22398   -9.448  -64.358                 NaN              NaN     NaN     NaN
#
#       FÍGADO SANGUE MEIO PRESERV. DEF. DATA COLETA DATA PREP. EMPRESTADO DATA  \
# 6202     NaN      X       Lysis buffer  02/08/2011        NaN        NaN  NaN
# 21420    NaN      X                NaN  26/08/2011        NaN        NaN  NaN
# 23330    NaN      X                NaN  19/09/2010        NaN        NaN  NaN
# 6028     NaN      X       Lysis buffer  01/07/2011        NaN        NaN  NaN
# 23126    NaN      X                NaN  21/06/2011        NaN        NaN  NaN
# 21512    NaN      X                NaN  30/08/2011        NaN        NaN  NaN
# 6010     NaN      X       Lysis buffer  07/06/2011        NaN        NaN  NaN
# 22773    NaN      X                NaN  27/05/2011        NaN        NaN  NaN
# 21087    NaN      X             Álcool  21/03/2013        NaN        NaN  NaN
# 22398    NaN      X                NaN  06/08/2010        NaN        NaN  NaN
#
#        GUIA N° PARA  Obs EMPRESTADO.1 DATA.1  GUIA N°.1 PARA.1 EMPRESTADO.2  \
# 6202       NaN  NaN  NaN          NaN    NaN        NaN    NaN          NaN
# 21420      NaN  NaN  NaN          NaN    NaN        NaN    NaN          NaN
# 23330      NaN  NaN  NaN          NaN    NaN        NaN    NaN          NaN
# 6028       NaN  NaN  NaN          NaN    NaN        NaN    NaN          NaN
# 23126      NaN  NaN  NaN          NaN    NaN        NaN    NaN          NaN
# 21512      NaN  NaN  NaN          NaN    NaN        NaN    NaN          NaN
# 6010       NaN  NaN  NaN          NaN    NaN        NaN    NaN          NaN
# 22773      NaN  NaN  NaN          NaN    NaN        NaN    NaN          NaN
# 21087      NaN  NaN  NaN          NaN    NaN        NaN    NaN          NaN
# 22398      NaN  NaN  NaN          NaN    NaN        NaN    NaN          NaN
#
#       DATA.2  GUIA N°.2 PARA.2 EMPRESTADO.3 DATA.3  GUIA N°.3 PARA.3
# 6202     NaN        NaN    NaN          NaN    NaN        NaN    NaN
# 21420    NaN        NaN    NaN          NaN    NaN        NaN    NaN
# 23330    NaN        NaN    NaN          NaN    NaN        NaN    NaN
# 6028     NaN        NaN    NaN          NaN    NaN        NaN    NaN
# 23126    NaN        NaN    NaN          NaN    NaN        NaN    NaN
# 21512    NaN        NaN    NaN          NaN    NaN        NaN    NaN
# 6010     NaN        NaN    NaN          NaN    NaN        NaN    NaN
# 22773    NaN        NaN    NaN          NaN    NaN        NaN    NaN
# 21087    NaN        NaN    NaN          NaN    NaN        NaN    NaN
# 22398    NaN        NaN    NaN          NaN    NaN        NaN    NaN

# %%
data_clean[data_clean['DATA PREP.'].isna() == True].sample(20)
# Out:
#             No TEC.                             Nome preparador  \
# 24333  INPA A 24339            João Capurucho, Marina Maximiano
# 24522  INPA A 24528                                         NaN
# 14309  INPA A 14315               Cassiano Gatto e Roberta Boss
# 23752  INPA A 23758                      Gisiane Rodrigues Lima
# 26862  INPA A 26868                                         NaN
# 14915  INPA A 14921                              Juliana Menger
# 11886  INPA A 11892                           Marcelo Barreiros
# 9038    INPA A 9044                              Juliana Menger
# 22397  INPA A 22403              Mônica S Ribas/Roberta L. Boss
# 21575  INPA A 21581                     Jaqueline Rizzi Fortuna
# 11328  INPA A 11334                           Marcelo Barreiros
# 26830  INPA A 26836                                         NaN
# 26193  INPA A 26199                            Marina Maximiano
# 16651  INPA A 16657               Cassiano Gatto e Roberta Boss
# 6005    INPA A 6011                                 Jared Wolfe
# 6358    INPA A 6364     Claudeir Ferreira Vargas e Alan Fecchio
# 9077    INPA A 9083                              Juliana Menger
# 23173  INPA A 23179              Mônica S Ribas/Roberta L. Boss
# 5071    INPA A 5077  Camila Ribas, Fernando Horta, Renato Gaban
# 5163    INPA A 5169  Camila Ribas, Fernando Horta, Renato Gaban
#
#                ORDEM           FAMÍLIA         GÊNERO         ESPÉCIE  \
# 24333  Passeriformes    Thamnophilidae    Myrmelastes     leucostigma
# 24522  Passeriformes     Troglodytidae    Cyphorhinus           arada
# 14309  Passeriformes    Thamnophilidae     Hylophylax         naevius
# 23752    Apodiformes       Trochilidae       Amazilia       fimbriata
# 26862   Tinamiformes         Tinamidae        Tinamus        guttatus
# 14915  Passeriformes    Thamnophilidae     Hypocnemis        cantator
# 11886  Passeriformes          Pipridae    Lepidothrix       nattereri
# 9038   Passeriformes  Dendrocolaptidae  Glyphorynchus        spirurus
# 22397  Passeriformes    Thamnophilidae   Myrmotherula        iheringi
# 21575  Passeriformes          Pipridae    Ceratopipra  erythrocephala
# 11328  Passeriformes          Pipridae    Ceratopipra    rubrocapilla
# 26830  Passeriformes       Furnariidae      Automolus      infuscatus
# 26193  Passeriformes    Thamnophilidae    Gymnopithys       leucaspis
# 16651  Passeriformes    Thamnophilidae     Phlegopsis   nigromaculata
# 6005   Passeriformes  Dendrocolaptidae  Glyphorynchus        spirurus
# 6358   Passeriformes    Thamnophilidae   Thamnophilus        aethiops
# 9077   Passeriformes    Thamnophilidae     Hypocnemis        cantator
# 23173  Passeriformes          Pipridae    Ceratopipra    rubrocapilla
# 5071   Passeriformes    Thamnophilidae     Cercomacra     cinerascens
# 5163   Columbiformes        Columbidae      Geotrygon         montana
#
#                    GÊNERO ESPÉCIE SEXO EST  \
# 24333     Myrmelastes leucostigma    M  AM
# 24522           Cyphorhinus arada    M  AM
# 14309          Hylophylax naevius    F  PA
# 23752          Amazilia fimbriata  NaN  AM
# 26862            Tinamus guttatus  NaN  AM
# 14915         Hypocnemis cantator    F  AM
# 11886       Lepidothrix nattereri    F  PA
# 9038       Glyphorynchus spirurus  NaN  AM
# 22397       Myrmotherula iheringi    M  RO
# 21575  Ceratopipra erythrocephala  NaN  AM
# 11328    Ceratopipra rubrocapilla    I  PA
# 26830        Automolus infuscatus  NaN  AM
# 26193       Gymnopithys leucaspis  NaN  AM
# 16651    Phlegopsis nigromaculata    I  PA
# 6005       Glyphorynchus spirurus  NaN  AM
# 6358        Thamnophilus aethiops    M  AM
# 9077          Hypocnemis cantator  NaN  AM
# 23173    Ceratopipra rubrocapilla  NaN  RO
# 5071       Cercomacra cinerascens  NaN  MT
# 5163            Geotrygon montana  NaN  PA
#
#                                               LOCALIDADE area_endemism  \
# 24333  Parque Nacional Mapinguari, margem direita do ...      Inambari
# 24522  Resex Baixo Juruá, margem direita dos rios Jur...      Inambari
# 14309  PA: margem esquerda do Rio Tapajós; ca.50 km S...      Rondonia
# 23752  Rio Solmões, ca 15 Km W Codajás, Ilha Grande, ...      Inambari
# 26862  Interflúvio Madeira-Purús, Beruri, BR 319 N km...      Inambari
# 14915                              Manaus; Reserva Ducke        Guiana
# 11886  Margem esquerda do Rio Tapajós; 70 km sudoeste...      Rondonia
# 9038                               Manaus; Reserva Ducke        Guiana
# 22397  Porto Velho, margem direita do Rio Madeira; Mó...      Rondonia
# 21575  Rio Preto da Eva, BR 174 ca 60 km N de Manaus,...        Guiana
# 11328  Margem direita do Rio Tapajós; 102 km sudoeste...       Tapajos
# 26830  Interflúvio Madeira-Purús, Beruri, BR 319 N km...      Inambari
# 26193  Interflúvio Solimões-Negro, Iranduba, Ramal Aç...         Imeri
# 16651  Margens direita do Rio Tapajós e direita do Ja...       Tapajos
# 6005   Fragmentos PDBFF, BR-174 80 km NE Manaus, Dimo...        Guiana
# 6358   Margem direita do Rio Daraha, afluente da marg...        Guiana
# 9077                               Manaus; Reserva Ducke        Guiana
# 23173  Porto Velho; margem direita do Rio Madeira; Mó...      Rondonia
# 5071   Nova Bandeirantes, margem direita Rio Juruena,...      Rondonia
# 5163   Aveiro, Rio Tapajós, margem esquerda, Escrivão...      Rondonia
#
#        LAT_DEC  LON_DEC TEMPO ATÉ CONSERVAR   MÉTODO DE COLETA MÚSCULO  \
# 24333   -7.851  -63.857   24h até geladeira   Rede de neblina        X
# 24522   -3.832  -66.081                 NaN   Rede de neblina        X
# 14309   -4.495  -56.300                 NaN  Rede de neblina       NaN
# 23752   -3.813  -62.196                 NaN   Rede de neblina        X
# 26862   -6.022  -62.511                 NaN   Rede de neblina      NaN
# 14915   -2.943  -59.942                 NaN  Rede de neblina       NaN
# 11886   -4.713  -56.440                 NaN  Rede de neblina       NaN
# 9038    -2.943  -59.942                 NaN   Rede de neblina      NaN
# 22397   -9.448  -64.358                 NaN                NaN     NaN
# 21575   -2.451  -59.768                 NaN                NaN     NaN
# 11328   -5.113  -56.444                 NaN  Rede de neblina       NaN
# 26830   -5.972  -62.478                 NaN   Rede de neblina      NaN
# 26193   -3.109  -60.318                 NaN   Rede de neblina      NaN
# 16651   -5.083  -56.433                 NaN  Rede de neblina       NaN
# 6005    -2.342  -60.095                 NaN                NaN     NaN
# 6358    -0.400  -64.800                 NaN   Rede de neblina      NaN
# 9077    -2.943  -59.942                 NaN   Rede de neblina      NaN
# 23173   -9.449  -64.372                 NaN                NaN     NaN
# 5071   -10.383  -58.327                 NaN                NaN       X
# 5163    -3.705  -55.592                 NaN                NaN       X
#
#       CORAÇÃO FÍGADO SANGUE MEIO PRESERV. DEF. DATA COLETA DATA PREP.  \
# 24333     NaN    NaN    NaN        Álcool 100%  25/11/2017        NaN
# 24522     NaN    NaN    NaN        Álcool 100%  14/07/2018        NaN
# 14309     NaN    NaN      X             Álcool  11/04/2013        NaN
# 23752     NaN    NaN    NaN        Álcool 100%  04/11/2017        NaN
# 26862     NaN    NaN      X        Álcool 100%  29/10/2019        NaN
# 14915     NaN    NaN      X     Queen's buffer  06/09/2013        NaN
# 11886     NaN    NaN      X         Álcool 95%  30/04/2013        NaN
# 9038      NaN    NaN      X             Álcool  20/08/2012        NaN
# 22397     NaN    NaN      X                NaN  06/08/2010        NaN
# 21575     NaN    NaN      X                NaN  05/08/2008        NaN
# 11328     NaN    NaN      X         Álcool 70%  09/12/2012        NaN
# 26830     NaN    NaN      X        Álcool 100%  26/10/2019        NaN
# 26193     NaN    NaN      X        Álcool 100%  11/09/2019        NaN
# 16651     NaN    NaN      X             Álcool  16/10/2013        NaN
# 6005      NaN    NaN      X       Lysis buffer  17/07/2011        NaN
# 6358      NaN    NaN      X             Álcool  03/04/2012        NaN
# 9077      NaN    NaN      X             Álcool  23/08/2012        NaN
# 23173     NaN    NaN      X                NaN  07/10/2011        NaN
# 5071      NaN    NaN    NaN   Álcool ou tampão  21/08/2003        NaN
# 5163      NaN    NaN    NaN             Álcool  05/12/2003        NaN
#
#       EMPRESTADO DATA  GUIA N° PARA  Obs EMPRESTADO.1 DATA.1  GUIA N°.1  \
# 24333        NaN  NaN      NaN  NaN  NaN          NaN    NaN        NaN
# 24522        NaN  NaN      NaN  NaN  NaN          NaN    NaN        NaN
# 14309        NaN  NaN      NaN  NaN  NaN          NaN    NaN        NaN
# 23752        NaN  NaN      NaN  NaN  NaN          NaN    NaN        NaN
# 26862        NaN  NaN      NaN  NaN  NaN          NaN    NaN        NaN
# 14915        NaN  NaN      NaN  NaN  NaN          NaN    NaN        NaN
# 11886        NaN  NaN      NaN  NaN  NaN          NaN    NaN        NaN
# 9038         NaN  NaN      NaN  NaN  NaN          NaN    NaN        NaN
# 22397        NaN  NaN      NaN  NaN  NaN          NaN    NaN        NaN
# 21575        NaN  NaN      NaN  NaN  NaN          NaN    NaN        NaN
# 11328        NaN  NaN      NaN  NaN  NaN          NaN    NaN        NaN
# 26830        NaN  NaN      NaN  NaN  NaN          NaN    NaN        NaN
# 26193        NaN  NaN      NaN  NaN  NaN          NaN    NaN        NaN
# 16651        NaN  NaN      NaN  NaN  NaN          NaN    NaN        NaN
# 6005         NaN  NaN      NaN  NaN  NaN          NaN    NaN        NaN
# 6358         NaN  NaN      NaN  NaN  NaN          NaN    NaN        NaN
# 9077         NaN  NaN      NaN  NaN  NaN          NaN    NaN        NaN
# 23173        NaN  NaN      NaN  NaN  NaN          NaN    NaN        NaN
# 5071         NaN  NaN      NaN  NaN  NaN          NaN    NaN        NaN
# 5163         NaN  NaN      NaN  NaN  NaN          NaN    NaN        NaN
#
#       PARA.1 EMPRESTADO.2 DATA.2  GUIA N°.2 PARA.2 EMPRESTADO.3 DATA.3  \
# 24333    NaN          NaN    NaN        NaN    NaN          NaN    NaN
# 24522    NaN          NaN    NaN        NaN    NaN          NaN    NaN
# 14309    NaN          NaN    NaN        NaN    NaN          NaN    NaN
# 23752    NaN          NaN    NaN        NaN    NaN          NaN    NaN
# 26862    NaN          NaN    NaN        NaN    NaN          NaN    NaN
# 14915    NaN          NaN    NaN        NaN    NaN          NaN    NaN
# 11886    NaN          NaN    NaN        NaN    NaN          NaN    NaN
# 9038     NaN          NaN    NaN        NaN    NaN          NaN    NaN
# 22397    NaN          NaN    NaN        NaN    NaN          NaN    NaN
# 21575    NaN          NaN    NaN        NaN    NaN          NaN    NaN
# 11328    NaN          NaN    NaN        NaN    NaN          NaN    NaN
# 26830    NaN          NaN    NaN        NaN    NaN          NaN    NaN
# 26193    NaN          NaN    NaN        NaN    NaN          NaN    NaN
# 16651    NaN          NaN    NaN        NaN    NaN          NaN    NaN
# 6005     NaN          NaN    NaN        NaN    NaN          NaN    NaN
# 6358     NaN          NaN    NaN        NaN    NaN          NaN    NaN
# 9077     NaN          NaN    NaN        NaN    NaN          NaN    NaN
# 23173    NaN          NaN    NaN        NaN    NaN          NaN    NaN
# 5071     NaN          NaN    NaN        NaN    NaN          NaN    NaN
# 5163     NaN          NaN    NaN        NaN    NaN          NaN    NaN
#
#        GUIA N°.3 PARA.3
# 24333        NaN    NaN
# 24522        NaN    NaN
# 14309        NaN    NaN
# 23752        NaN    NaN
# 26862        NaN    NaN
# 14915        NaN    NaN
# 11886        NaN    NaN
# 9038         NaN    NaN
# 22397        NaN    NaN
# 21575        NaN    NaN
# 11328        NaN    NaN
# 26830        NaN    NaN
# 26193        NaN    NaN
# 16651        NaN    NaN
# 6005         NaN    NaN
# 6358         NaN    NaN
# 9077         NaN    NaN
# 23173        NaN    NaN
# 5071         NaN    NaN
# 5163         NaN    NaN

# %%
data_clean['DATA PREP.'].isnull().sum()
# Out:
# 11748

# %% [markdown]
# **SUMMARY OF MISSING DATA INFORMATION**
#
# * Nome of the preparador: This information is crucial but a minor part (2k records) of this field is missing.
#
#
# * Sexo: About 1/4 of the records have missing inforamation. The remaining records lack standardization. This needs to be seriously improved, the values should only me Male (M), Female (F), and undetermined (I). When unknown, this should be coded as 'I' and not missing. A serious standardization is required as it is not even possible to understand some of the values used to correct. This should be discussed and oriented to future collector and with the person responsible for inputing data.
#
#
# * Metodo de coleta: These are likely either to not have been filled in the datasheet by the collector or by the person who input data in the collection since many of records the general completeness of the record does not indicate other reason
#
#
# * Data de preparacao: About half of the missing information is represented by blood samples, which typically don't have a preparation because there is generally no skin specimen associated. The curator needs to decide if preparation time should be the same as the collection date or if kept missing.

# %% [markdown]
# ## General representativeness of the collection

# %% [markdown]
# > Let's plot some nice graphs to see how the samples are distributed along the different categories

# %% [markdown]
# ### Taxonomic category

# %%
data_clean[~data_clean['ORDEM'].isnull()]['ORDEM'].unique()
# Out:
# array(['Passeriformes', 'Piciformes', 'Galbuliformes', 'Charadriiformes',
#        'Gruiformes', 'Psittaciformes', 'Apodiformes', 'Galliformes',
#        'Caprimulgiformes', 'Cuculiformes', 'Tinamiformes',
#        'Falconiformes', 'Pelecaniformes', 'Strigiformes', 'Coraciiformes',
#        'Columbiformes', 'Accipitriformes', 'Nyctibiiformes',
#        'Trogoniformes', 'Opisthocomiformes', 'Anseriformes',
#        'Eurypygiformes', 'Suliformes', 'Cathartiformes'], dtype=object)

# %%
len(data_clean[~data_clean['ORDEM'].isnull()]['ORDEM'].unique())
# Out:
# 24

# %%
plt.figure(figsize=(14, 10))
ax = sns.countplot(x=data_clean['ORDEM'],order=data_clean['ORDEM'].value_counts(10).iloc[0:10].index,palette='tab10')
plt.title('Top 10 most collected bird Orders',fontsize=20)
plt.xlabel('Bird Orders',fontsize=15)
plt.ylabel('Number of Specimens',fontsize=15)

add_perc(ax,data_clean['ORDEM'])

# %%
(data_clean['ORDEM'].value_counts()/data_clean['ORDEM'].value_counts().sum())[0:10]
# Out:
# Passeriformes       0.869954
# Apodiformes         0.036552
# Psittaciformes      0.018125
# Galbuliformes       0.016992
# Piciformes          0.014915
# Columbiformes       0.011215
# Coraciiformes       0.006532
# Caprimulgiformes    0.005022
# Trogoniformes       0.003285
# Accipitriformes     0.002832
# Name: ORDEM, dtype: float64

# %%
plt.figure(figsize=(15, 10))
ax = sns.countplot(x=data_clean['ORDEM'],order=data_clean['ORDEM'].value_counts(10).iloc[1:11].index,palette='tab10')
plt.title('Top 10 most collected bird Orders - Passeriformes not included',fontsize=20)
plt.xlabel('Bird Orders',fontsize=15)
plt.ylabel('Number of Specimens',fontsize=15)

add_perc(ax,data_clean['ORDEM'])

# %%
plt.figure(figsize=(14, 10))
ax = sns.countplot(x=data_clean['FAMÍLIA'],order=data_clean['FAMÍLIA'].value_counts(10).iloc[0:10].index,palette='tab10')
plt.title('Top 10 most collected bird Families',fontsize=20)
plt.xlabel('Bird Family',fontsize=15)
plt.ylabel('Number of Specimens',fontsize=15)

add_perc(ax,data_clean['FAMÍLIA'])

# %%
data_clean['FAMÍLIA'].value_counts()/data_clean['FAMÍLIA'].value_counts().sum()
# Out:
# Thamnophilidae       0.312842
# Pipridae             0.146283
# Dendrocolaptidae     0.126458
# Tyrannidae           0.048484
# Thraupidae           0.046634
#                        ...
# Jacanidae            0.000076
# Laridae              0.000038
# Threskiornithidae    0.000038
# Oxyruncidae          0.000038
# Recurvirostridae     0.000038
# Name: FAMÍLIA, Length: 76, dtype: float64

# %%
# 100 * data_clean_c['sales'] / data_clean.groupby('state')['sales'].transform('sum')
percentage_families = pd.DataFrame({'Percentage':data_clean.groupby(by='FAMÍLIA').size()/len(data_clean)}).sort_values(by='Percentage',ascending=False)

# %%
series = pd.value_counts(data_clean['FAMÍLIA'])
mask = (series/series.sum() * 100).lt(1)
percentage_families = series[~mask]/sum(series)*100
percentage_families['Other'] = series[mask].sum()/sum(series)*100
percentage_families.sort_values(ascending=False,inplace=True)
percentage_families
# Out:
# Thamnophilidae      31.284220
# Pipridae            14.628252
# Dendrocolaptidae    12.645848
# Other               12.336216
# Tyrannidae           4.848393
# Thraupidae           4.663369
# Rhynchocyclidae      3.911944
# Trochilidae          3.617415
# Furnariidae          2.511045
# Psittacidae          1.812483
# Turdidae             1.789827
# Tityridae            1.363139
# Troglodytidae        1.298946
# Onychorhynchidae     1.147906
# Columbidae           1.121474
# Formicariidae        1.019522
# Name: FAMÍLIA, dtype: float64

# %%
series = pd.value_counts(data_clean['GÊNERO'])
mask = (series/series.sum() * 100).lt(1)
percentage_genera = series[~mask]/sum(series)*100
percentage_genera['Other'] = series[mask].sum()/sum(series)*100
percentage_genera.sort_values(ascending=False,inplace=True)
percentage_genera
# Out:
# Other             43.340883
# Glyphorynchus      4.911287
# Dixiphia           4.035485
# Lepidothrix        3.793884
# Myrmotherula       3.695734
# Willisornis        3.250283
# Thamnomanes        3.038883
# Xiphorhynchus      2.789732
# Pithys             2.785957
# Dendrocincla       2.668932
# Thamnophilus       2.189505
# Elaenia            2.140430
# Mionectes          2.042280
# Xenopipo           2.004530
# Ceratopipra        1.929030
# Hypocnemis         1.834655
# Epinecrophylla     1.728954
# Phaethornis        1.664779
# Turdus             1.664779
# Myrmoborus         1.589279
# Gymnopithys        1.442054
# Tachyphonus        1.147603
# Pyrrhura           1.140053
# Schiffornis        1.098528
# Automolus          1.057003
# Formicarius        1.015478
# Name: GÊNERO, dtype: float64

# %%
plt.figure(figsize=(14, 10))
ax = sns.countplot(x=data_clean['GÊNERO'],order=data_clean['GÊNERO'].value_counts(10).iloc[0:10].index,palette='tab10')
plt.title('Top 10 most collected bird Genera',fontsize=20)
plt.xlabel('Bird Genera',fontsize=15)
plt.ylabel('Number of Specimens',fontsize=15)

add_perc(ax,data_clean['GÊNERO'])

# %%
plt.figure(figsize=(21, 10))
ax = sns.countplot(x=data_clean['GÊNERO ESPÉCIE'],order=data_clean['GÊNERO ESPÉCIE'].value_counts(10).iloc[0:10].index,palette='tab10')
plt.title('Top 10 most collected bird Species',fontsize=20)
plt.xlabel('Bird Species',fontsize=15)
plt.ylabel('Number of Specimens',fontsize=15)

bar_percentage(ax,data_clean['GÊNERO ESPÉCIE'])

# %%
least_collected_families = data_clean['FAMÍLIA'].value_counts().loc[lambda x : x<5].to_frame().reset_index().set_axis(['Family','Samples'],axis=1).sort_values(by=['Samples','Family'])
least_collected_families
# Out:
#                Family  Samples
# 11            Laridae        1
# 13        Oxyruncidae        1
# 14   Recurvirostridae        1
# 12  Threskiornithidae        1
# 6           Anhimidae        2
# 9          Anhingidae        2
# 8            Aramidae        2
# 10          Jacanidae        2
# 7         Pandionidae        2
# 5           Sternidae        2
# 3         Eurypygidae        3
# 4      Opisthocomidae        3
# 2   Phalacrocoracidae        3
# 1        Donacobiidae        4
# 0      Rhinocryptidae        4

# %%
pd.set_option("display.max_rows", None)
least_collected_genera = data_clean['GÊNERO'].value_counts().loc[lambda x : x<5].to_frame().reset_index().set_axis(['Genus','Samples'],axis=1).sort_values(by=['Samples','Genus'])

# %%
least_collected_genera.to_csv('./results/least_collected_genera.csv')

# %%
least_collected_species = data_clean['GÊNERO ESPÉCIE'].value_counts().loc[lambda x : x<5].to_frame().reset_index().set_axis(['Species','Samples'],axis=1).sort_values(by=['Samples','Species'])
least_collected_species
# Out:
#                                   Species  Samples
# 437                    Accipiter striatus        1
# 554                    Actitis macularius        1
# 374                 Amazilia brevirostris        1
# 488                     Amazona amazonica        1
# 396                  Amazona coerulescens        1
# 541                      Amazona farinosa        1
# 559                  Ammodramus humeralis        1
# 515            Antrostomus sericocaudatus        1
# 350              Anurolimnas castaneiceps        1
# 568                      Ara chloropterus        1
# 543                             Ara macao        1
# 517                            Ardea alba        1
# 500             Arundinicola leucocephala        1
# 512                     Atticora tibialis        1
# 379                 Attila citriniventris        1
# 470                    Attila phoenicurus        1
# 534                            Attila sp.        1
# 473              Aulacorhynchus derbianus        1
# 367              Automolus cf. infuscatus        1
# 524                 Automolus melanopezus        1
# 486                         Automolus sp.        1
# 386                  Bartramia longicauda        1
# 555                        Brotogeris sp.        1
# 432                      Buteo brachyurus        1
# 501                             Buteo sp.        1
# 548               Buteogallus schistaceus        1
# 404         Campylorhamphus gyldenstolpei        1
# 358                 Campylorhamphus sanus        1
# 407                      Caracara plancus        1
# 427                 Cathartes burrovianus        1
# 344                  Catharus cf. minimus        1
# 425                      Catharus minimus        1
# 538                    Catharus swainsoni        1
# 531                Celeus elegans jumanus        1
# 497                      Celeus ochraceus        1
# 330                      Chamaeza nobilis        1
# 467                     Chlorostilbon sp.        1
# 459               Chondrohierax uncinatus        1
# 507                        Chordeiles sp.        1
# 466             Cnemotriccus cf. fuscatus        1
# 525           Cnipodectes cf. subbrunneus        1
# 430                Cnipodectes superrufus        1
# 510                   Coccyzus americanus        1
# 485                Colaptes melanochloros        1
# 550                     Colinus cristatus        1
# 494                       Colonia colonus        1
# 333                   Conopophaga lineata        1
# 546                  Conopophaga melanops        1
# 428                      Contopus cooperi        1
# 468                   Contopus sordidulus        1
# 461             Coryphospingus cucullatus        1
# 429                 Cranioleuca stellaris        1
# 439                        Crax globulosa        1
# 363                        Crotophaga ani        1
# 516                        Crotophaga sp.        1
# 342                Crypturellus obsoletus        1
# 375                      Crypturellus sp.        1
# 474                         Daptrius ater        1
# 336               Dendrexetastes rufigula        1
# 93                         Tolmomyias sp.        3
# 139                           Topaza pyra        3
# 165                      Tringa solitaria        3
# 98                        Trochilidae sp.        3
# 175                      Turdus nudigenis        3
# 169                    Turdus sanchezorum        3
# 164                        Tyrannidae sp.        3
# 75                        Xenops rutilans        3
# 32                     Akletos melanoceps        4
# 29      Amazilia viridigaster cupreicauda        4
# 52                 Arremonops conirostris        4
# 70                          Asio clamator        4
# 47                   Brachygalba lugubris        4
# 74                   Calidris fuscicollis        4
# 64                     Calidris melanotos        4
# 72                   Campylopterus duidae        4
# 12                   Cantorchilus griseus        4
# 54                      Caracara cheriway        4
# 31                    Chiroxiphia caudata        4
# 42                 Chloroceryle americana        4
# 20                 Chordeiles acutipennis        4
# 50                   Clibanornis obscurus        4
# 3                        Cnemotriccus sp.        4
# 53                      Colibri delphinae        4
# 45                        Conopias parvus        4
# 35               Conopophaga melanogaster        4
# 1                    Cranioleuca muelleri        4
# 73                           Crax alector        4
# 16                      Cyanerpes cyaneus        4
# 0                  Donacobius atricapilla        4
# 25                      Doryfera johannae        4
# 58                     Dryocopus lineatus        4
# 56                        Elaenia olivina        4
# 68              Epinecrophylla pyrrhonota        4
# 33                    Eubucco richardsoni        4
# 30                      Euphonia violacea        4
# 9                     Eupsittula pertinax        4
# 34                       Formicivora rufa        4
# 27                        Furnarius minor        4
# 51                 Glaucidium brasilianum        4
# 5                    Granatellus pelzelni        4
# 44              Graydidascalus brachyurus        4
# 28                     Hemithraupis guira        4
# 39                    Hemitriccus minimus        4
# 22                 Herpsilochmus roraimae        4
# 37                   Herpsilochmus stotzi        4
# 7                    Hylopezus macularius        4
# 43                  Hylophilus pectoralis        4
# 59                  Lepidocolaptes duidae        4
# 21                   Liosceles thoracicus        4
# 4                 Lurocalis semitorquatus        4
# 65                 Malacoptila semicincta        4
# 71               Mionectes cf. oleagineus        4
# 8                   Myiothlypis mesoleuca        4
# 11                     Myrmothera simplex        4
# 62                      Neocrex erythrops        4
# 60                     Neopipo cinnamomea        4
# 57                Odontophorus gujanensis        4
# 24                        Ortalis guttata        4
# 15                         Ortalis motmot        4
# 2                  Pachyramphus surinamus        4
# 61                 Pachysylvia hypoxantha        4
# 46                   Picumnus spilogaster        4
# 49                          Piranga lutea        4
# 48               Poecilotriccus fumifrons        4
# 38                  Poecilotriccus sylvia        4
# 13                     Polioptila plumbea        4
# 63                Psarocolius bifasciatus        4
# 67                    Pyriglena leuconota        4
# 41                      Pyrrhura amazonum        4
# 36                      Querula purpurata        4
# 19                          Sclerurus sp.        4
# 40                     Selenidera gouldii        4
# 17                     Sporophila lineola        4
# 26                          Strix virgata        4
# 55                   Sublegatus obscurior        4
# 66                    Syndactyla roraimae        4
# 69                   Tangara xanthogastra        4
# 23              Thamnophilus cryptoleucus        4
# 10                  Thamnophilus insignis        4
# 6            Tolmomyias cf. sulphurescens        4
# 18                  Turdus amaurochalinus        4
# 14                     Xenopipo uniformis        4

# %%
# I will exclude samples which are not fully identified, which are the ones contain the suffixes sp. and cf.
# 100                 Nonnula amaurocephala        3
# 102                  Nyctibius bracteatus        3
# 143                     Nyctibius grandis        3
# 185                Nyctiphrynus ocellatus        3
# 119                   Opisthocomus hoazin        3
# 92                       Ornithion inerme        3
# 133               Orthopsittaca manilatus        3
# 174               Parkesia noveboracensis        3
# 150               Patagioenas cayennensis        3
# 131                   Patagioenas plumbea        3
# 148             Phaethornis griseogularis        3
# 126                Pharomachrus pavoninus        3
# 116                Philydor erythropterum        3
# 87                     Piaya melanogaster        3
# 111                    Picumnus undulatus        3
# 78                          Piranga rubra        3
# 124                       Podager nacunda        3
# 85                 Porphyrio flavirostris        3
# 95                  Procacicus solitarius        3
# 118              Psarocolius angustifrons        3
# 163               Pygochelidon cyanoleuca        3
# 120                    Pyrilia barrabandi        3
# 80                      Pyrilia vulturina        3
# 161                      Pyrrhura perlata        3
# 130                   Pyrrhura roseifrons        3
# 178                     Ramphodon naevius        3
# 104               Ramphotrigon fuscicauda        3
# 177                       Riparia riparia        3
# 145                 Rostrhamus sociabilis        3
# 108                     Rupicola rupicola        3
# 96                  Schiffornis virescens        3
# 125                 Sclerurus albigularis        3
# 103                  Selenidera nattereri        3
# 113                   Setophaga ruticilla        3
# 97                      Setophaga striata        3
# 160                    Sicalis columbiana        3
# 149                       Sicalis luteola        3
# 171                Synallaxis ruficapilla        3
# 187                Tachycineta albiventer        3
# 184                     Tangara schrankii        3
# 90                     Tiaris fuliginosus        3
# 155                    Tigrisoma lineatum        3
# 158    Tolmomyias flaviventris viridiceps        3
# 139                           Topaza pyra        3
# 165                      Tringa solitaria        3
# 175                      Turdus nudigenis        3
# 169                    Turdus sanchezorum        3
# 75                        Xenops rutilans        3
# 32                     Akletos melanoceps        4
# 29      Amazilia viridigaster cupreicauda        4
# 52                 Arremonops conirostris        4
# 70                          Asio clamator        4
# 47                   Brachygalba lugubris        4
# 74                   Calidris fuscicollis        4
# 64                     Calidris melanotos        4
# 72                   Campylopterus duidae        4
# 12                   Cantorchilus griseus        4
# 54                      Caracara cheriway        4
# 31                    Chiroxiphia caudata        4
# 42                 Chloroceryle americana        4
# 20                 Chordeiles acutipennis        4
# 50                   Clibanornis obscurus        4
# 53                      Colibri delphinae        4
# 45                        Conopias parvus        4
# 35               Conopophaga melanogaster        4
# 1                    Cranioleuca muelleri        4
# 73                           Crax alector        4
# 16                      Cyanerpes cyaneus        4
# 0                  Donacobius atricapilla        4
# 25                      Doryfera johannae        4
# 58                     Dryocopus lineatus        4
# 56                        Elaenia olivina        4
# 68              Epinecrophylla pyrrhonota        4
# 33                    Eubucco richardsoni        4
# 30                      Euphonia violacea        4
# 9                     Eupsittula pertinax        4
# 34                       Formicivora rufa        4
# 27                        Furnarius minor        4
# 51                 Glaucidium brasilianum        4
# 5                    Granatellus pelzelni        4
# 44              Graydidascalus brachyurus        4
# 28                     Hemithraupis guira        4
# 39                    Hemitriccus minimus        4
# 22                 Herpsilochmus roraimae        4
# 37                   Herpsilochmus stotzi        4
# 7                    Hylopezus macularius        4
# 43                  Hylophilus pectoralis        4
# 59                  Lepidocolaptes duidae        4
# 21                   Liosceles thoracicus        4
# 4                 Lurocalis semitorquatus        4
# 65                 Malacoptila semicincta        4
# 8                   Myiothlypis mesoleuca        4
# 11                     Myrmothera simplex        4
# 62                      Neocrex erythrops        4
# 60                     Neopipo cinnamomea        4
# 57                Odontophorus gujanensis        4
# 24                        Ortalis guttata        4
# 15                         Ortalis motmot        4
# 2                  Pachyramphus surinamus        4
# 61                 Pachysylvia hypoxantha        4
# 49                          Piranga lutea        4
# 48               Poecilotriccus fumifrons        4
# 38                  Poecilotriccus sylvia        4
# 13                     Polioptila plumbea        4
# 63                Psarocolius bifasciatus        4
# 67                    Pyriglena leuconota        4
# 41                      Pyrrhura amazonum        4
# 36                      Querula purpurata        4
# 40                     Selenidera gouldii        4
# 17                     Sporophila lineola        4
# 26                          Strix virgata        4
# 55                   Sublegatus obscurior        4
# 66                    Syndactyla roraimae        4
# 69                   Tangara xanthogastra        4
# 23              Thamnophilus cryptoleucus        4
# 10                  Thamnophilus insignis        4
# 18                  Turdus amaurochalinus        4
# 14                     Xenopipo uniformis        4

# %%
least_collected_species.to_csv('./results/least_collected_species.csv')

# %%
least_collected_families = data_clean['FAMÍLIA'].value_counts().loc[lambda x : x<5].to_frame().reset_index().set_axis(['Família','Samples'],axis=1).sort_values(by=['Samples','Família'])
least_collected_families
# Out:
#               Família  Samples
# 14            Laridae        1
# 12        Oxyruncidae        1
# 13   Recurvirostridae        1
# 11  Threskiornithidae        1
# 10          Anhimidae        2
# 8          Anhingidae        2
# 6            Aramidae        2
# 9           Jacanidae        2
# 7         Pandionidae        2
# 5           Sternidae        2
# 2         Eurypygidae        3
# 4      Opisthocomidae        3
# 3   Phalacrocoracidae        3
# 0        Donacobiidae        4
# 1      Rhinocryptidae        4

# %%
least_collected_orders = data_clean['ORDEM'].value_counts().loc[lambda x : x<5].to_frame().reset_index().set_axis(['Ordem','Samples'],axis=1).sort_values(by=['Samples','Ordem'])
least_collected_orders
# Out:
#                Ordem  Samples
# 0     Eurypygiformes        3
# 1  Opisthocomiformes        3

# %% [markdown]
# ### Sex

# %% [markdown]
# * What proportion of samples are males and females?

# %%
data_sex = data_clean[(data_clean['SEXO'] == 'M')| (data_clean['SEXO'] == 'F')]

# %%
plt.figure(figsize=(7, 5))
ax = sns.countplot(x=data_sex['SEXO'],order=data_sex['SEXO'].value_counts().index)
plt.title('Genetic samples by sex',fontsize=17)
plt.xlabel('Sex',fontsize=15)
plt.ylabel('Number of specimens',fontsize=15)

add_perc(ax,data_sex['SEXO'])

# %%
#Filtering by tissue samples
plt.figure(figsize=(7, 5))
ax = sns.countplot(x=data_sex[data_sex['MÚSCULO'] == 'X']['SEXO'],order=data_sex[data_sex['MÚSCULO'] == 'X']['SEXO'].value_counts().index)
plt.title('Tissue samples by sex',fontsize=17)
plt.xlabel('Sex',fontsize=15)
plt.ylabel('Number of specimens',fontsize=15)

add_perc(ax,data_sex[data_sex['MÚSCULO'] == 'X']['SEXO'])

# %%
#Filtering by blood samples
plt.figure(figsize=(7, 5))
ax = sns.countplot(x=data_sex[data_sex['SANGUE'] == 'X']['SEXO'],order=data_sex[data_sex['SANGUE'] == 'X']['SEXO'].value_counts().index)
plt.title('Blood samples by sex',fontsize=17)
plt.xlabel('Sex',fontsize=15)
plt.ylabel('Number of specimens',fontsize=15)

add_perc(ax,data_sex[data_sex['SANGUE'] == 'X']['SEXO'])

# %%
data_sex['MÉTODO DE COLETA'].value_counts()
# Out:
# Rede de neblina                   3522
# Tiro                               577
# Encontrado morto                    18
# tiro                                14
# Morreu na Rede de neblina            8
# Manual                               6
# Enc. morto                           4
# Enc. Morto                           3
# Achado morto                         3
# Bateu na janela                      2
# Doação                               2
# Atropelamento                        2
# Baladeira                            2
# Bateu na janela                      1
# Encontrado morto na rua              1
# Coleta oportuna(caiu no rio)         1
# Vivo debilitado, depois morreu       1
# Acidente                             1
# bateu no vidro                       1
# Cativo                               1
# Sacrificado                          1
# Name: MÉTODO DE COLETA, dtype: int64

# %% [markdown]
# ___
# **We can see that most samples are males, two hypothesis are likely to explain that**
#
# 1) **Males are more conspicuous (colorful) than females:** That could be corroborated if males were more collected by shot than females. However, this should not, or would not necessary, hold for specimens collected by mistnest because this method doesn't select target by visual instincts.
#
# 2) **Males move around more than females**: thus they are more likely to fall into the mistnets. In some bird families however, females move around more to look for reproducing arenas (leks) composed only by males. If that is true, then we should see the opposite pattern for these families.
#
# 3) **Females are less conspicous than males**: So they are not being properly identified during the labeling process of samples. In this hypothesis this bias is a mere lack of precision in identifying the samples' sex and not a real pattern.

# %% [markdown]
# * **Let's test Hypothesis 1**

# %%
#Filtering by method of collecting, mistnets
plt.figure(figsize=(7, 5))
ax = sns.countplot(x=data_sex[data_sex['MÉTODO DE COLETA'] == 'Rede de neblina']['SEXO'],order=data_sex[data_sex['MÉTODO DE COLETA'] == 'Rede de neblina']['SEXO'].value_counts().index)
plt.title('Genetic samples collected with mistnets',fontsize=17)
plt.xlabel('Sex',fontsize=15)
plt.ylabel('Number of specimens',fontsize=15)

add_perc(ax,data_sex[data_sex['MÉTODO DE COLETA'] == 'Rede de neblina']['SEXO'])

# %%
#Filtering by method of collecting, shot
plt.figure(figsize=(7, 5))
ax = sns.countplot(x=data_sex[data_sex['MÉTODO DE COLETA'] == 'Tiro']['SEXO'],order=data_sex[data_sex['MÉTODO DE COLETA'] == 'Tiro']['SEXO'].value_counts().index)
plt.title('Genetic samples collected by shot',fontsize=17)
plt.xlabel('Sex',fontsize=15)
plt.ylabel('Number of specimens',fontsize=15)

add_perc(ax,data_sex[data_sex['MÉTODO DE COLETA'] == 'Tiro']['SEXO'])

# %% [markdown]
# **Hypothesis 1**: The difference among sex in specimens collected by shot is much more pronouced than in samples collected by mistnets which corroborates hypothesis 1. However we still have a big difference in samples collected by mistnets

# %% [markdown]
# * **Let's test hypothesis 2**

# %%
plt.figure(figsize=(7, 5))
ax = sns.countplot(x=data_sex[data_sex['FAMÍLIA'] == 'Pipridae']['SEXO'])
plt.title('Genetic samples of the Pipridae Family by Sex',fontsize=17)
plt.xlabel('Sex',fontsize=15)
plt.ylabel('Number of specimens',fontsize=15)

add_perc(ax,data_sex[data_sex['FAMÍLIA'] == 'Pipridae']['SEXO'])

# %%
plt.figure(figsize=(7, 5))
ax = sns.countplot(x=data_sex[(data_sex['FAMÍLIA'] == 'Pipridae') | (data_sex['MÚSCULO'] == 'X')]['SEXO'],order=data_sex[(data_sex['FAMÍLIA'] == 'Pipridae') | (data_sex['MÚSCULO'] == 'X')]['SEXO'].value_counts().index)
plt.title('Tisse samples of the Pipridae Family by Sex',fontsize=17)
plt.xlabel('Sex',fontsize=15)
plt.ylabel('Number of specimens',fontsize=15)

add_perc(ax,data_sex[(data_sex['FAMÍLIA'] == 'Pipridae') | (data_sex['MÚSCULO'] == 'X')]['SEXO'])

# %%
plt.figure(figsize=(7, 5))
ax = sns.countplot(x=data_sex[(data_sex['FAMÍLIA'] == 'Pipridae') | (data_sex['SANGUE'] == 'X')]['SEXO'])
plt.title('Blood samples of the Pipridae Family by Sex',fontsize=17)
plt.xlabel('Sex',fontsize=15)
plt.ylabel('Number of specimens',fontsize=15)

add_perc(ax,data_sex[(data_sex['FAMÍLIA'] == 'Pipridae') | (data_sex['SANGUE'] == 'X')]['SEXO'])

# %% [markdown]
# **Hypothesis** 2 could not be corroborated as the pattern also holds for the Pipridae Family

# %% [markdown]
# * **Hypothesis 3** is much harder to test. We could compare the distribution of tissue and blood samples. Tissue samples are usually skin specimens which are identified based on gonads and does not rely on counspicouness of pluamge coloration. Thus we would expect that the difference is greater in blood than in tissue samples. That was not what we previously saw which does not corroborate H3 (see graph below). Maybe males are naturally more abundant?? Interesting question!

# %% [markdown]
# ** Let's make a good summary graph by sex **

# %%
sample_type_sexo = data_clean[(data_clean['SEXO'] == 'M') | (data_clean['SEXO'] == 'F')][['MÚSCULO','SANGUE','SEXO']]
df = sample_type_sexo.groupby('SEXO').count().reset_index()
tidy = df.melt(id_vars='SEXO').rename(columns=str.title)
tidy
# Out:
#   Sexo Variable  Value
# 0    F  MÚSCULO   3843
# 1    M  MÚSCULO   6110
# 2    F   SANGUE   2464
# 3    M   SANGUE   3318

# %%
plt.figure(figsize=(7, 5))
ax = sns.barplot(data=tidy,x='Variable', y='Value',hue='Sexo')
plt.title('Specimens by Sex',fontsize=20)
plt.xlabel('Sample type',fontsize=15)
plt.ylabel('Number of specimens',fontsize=15)

add_perc(ax,sample_type_sexo)

# %% [markdown]
# ### Top Collectors and Taxidermists

# %% [markdown]
# #### General collectors

# %%
top10_collectors = data_clean['Nome preparador'].value_counts().head(10)
top10_collectors
# Out:
# Gisiane Rodrigues Lima            2761
# Juliana Menger                    2037
# Cristiane Dreves                  1283
# Carolina Schuch de Oliveira       1210
# Cassiano Gatto e Roberta Boss      964
# Sebastião Carlos Pereira           940
# Mateus Ferreira                    910
# Mônica S Ribas/Roberta L. Boss     907
# Marcelo Barreiros                  902
# Jared Wolfe                        676
# Name: Nome preparador, dtype: int64

# %%
plt.figure(figsize=(27, 10))
ax = sns.countplot(x=data_clean['Nome preparador'],order=data_clean['Nome preparador'].value_counts().iloc[0:10].index,palette='tab10')
plt.title('Top 10 collectors or taxidermists',fontsize=20)
plt.xlabel('Person',fontsize=15)
plt.ylabel('Number of Specimens',fontsize=15)

add_perc(ax,data_clean['Nome preparador'])

# %% [markdown]
# ** I can see that we have blood collector and taxidermists together in the same group which is not ideally. Each column should contain only one type of information. I'll break them a part by filtering by tissue samples which will represent taxidermist and blood samples which will represent blood collectors. Unfortunately it is not possible to retrieve a rank of General collectors due to limitations of the data. Maybe in the future by crossing the skins specimen and genetic resources databases **

# %% [markdown]
# ##### Top taxidermists

# %%
top_taxidermists = pd.DataFrame({'Specimens':data_clean[data_clean['MÚSCULO'] == 'X']['Nome preparador'].value_counts().head(10)})
top_taxidermists.index.name = 'Name'
top_taxidermists
# Out:
#                                             Specimens
# Name
# Gisiane Rodrigues Lima                            997
# João Capurucho, Marina Maximiano                  282
# Alexandre Mendes Fernandes                        222
# Stephane dos Santos Pereira                       219
# Luciano Nicolás Naka                              213
# Cristiane Dreves                                  209
# Camila Ribas, Fernando Horta, Renato Gaban        182
# Emerson Boaventura                                139
# Érica Dantas de Lima                              135
# Elton Márcio de Pinho                             131

# %%
plt.figure(figsize=(14, 10))
ax = sns.countplot(x=data_clean[data_clean['MÚSCULO'] == 'X']['Nome preparador'],order=data_clean[data_clean['MÚSCULO'] == 'X']['Nome preparador'].value_counts().iloc[0:6].index,palette='tab10')
plt.title('Top taxidermists',fontsize=20)
plt.xlabel('Person',fontsize=15)
plt.ylabel('Number of prepared specimens',fontsize=15)

add_perc(ax,data_clean[data_clean['MÚSCULO'] == 'X']['Nome preparador'])

# %% [markdown]
# #### Top blood collectors

# %%
top_blood_collectors = pd.DataFrame({'Specimens':data_clean[data_clean['SANGUE'] == 'X']['Nome preparador'].value_counts().head(10)})
top_blood_collectors.index.name = 'Name'
top_blood_collectors
# Out:
#                              Specimens
# Name
# Jared Wolfe                        672
# Carolina Schuch de Oliveira        546
# Cintia Cornelius                   339
# Stéfano Spiteri Avilla             307
# Jaqueline Rizzi Fortuna            296
# Marina Maximiano                   286
# Affonso Henrique                   272
# Sérgio Henrique Borges             240
# Marco Aurélio Silva                239
# João Vítor Campos e Silva          222

# %%
plt.figure(figsize=(18, 10))
ax = sns.countplot(x=data_clean[data_clean['SANGUE'] == 'X']['Nome preparador'],order=data_clean[data_clean['SANGUE'] == 'X']['Nome preparador'].value_counts().iloc[0:6].index,palette='tab10')
plt.title('Top blood collectors',fontsize=20)
plt.xlabel('Person',fontsize=15)
plt.ylabel('Number of blood samples',fontsize=15)

add_perc(ax,data_clean[data_clean['SANGUE'] == 'X']['Nome preparador'])

# %%
plt.figure(figsize=(14, 10))
ax = sns.countplot(x=data_clean['EST'],order=data_clean['EST'].value_counts().iloc[0:12].index,palette='tab10')
plt.title('Specimens per state',fontsize=20)
plt.xlabel('State',fontsize=15)
plt.ylabel('Number of Specimens',fontsize=15)

add_perc(ax,data_clean['EST'])

# %%
# ax = data_clean['EST'].value_counts().to_frame().plot.pie(y='EST',figsize=(5,5))
plt.figure(figsize=(8,8))
plt.pie(data_clean['EST'].value_counts().to_frame()['EST'], labels = data_clean['EST'].value_counts().to_frame().index, autopct='%.0f%%')
plt.show()

# %%
plt.figure(figsize=(14, 10))
ax = sns.countplot(x=data_clean['EST'],order=data_clean['EST'].value_counts().iloc[0:6].index,palette='tab10')
plt.title('Top 6 States with more collecting',fontsize=20)
plt.xlabel('State',fontsize=15)
plt.ylabel('Number of Specimens',fontsize=15)

add_perc(ax,data_clean['EST'])

# %%
plt.figure(figsize=(14, 10))
ax = sns.countplot(x=data_clean['EST'],order=data_clean['EST'].value_counts(10).iloc[-6:].index,palette='tab10')
plt.title('States with less collecting',fontsize=20)
plt.xlabel('State',fontsize=15)
plt.ylabel('Number of Specimens',fontsize=15)

add_perc(ax,data_clean['EST'])

# plt.figure(figsize=(25, 15))
# sns.countplot(x=data_clean['EST'],order=data_clean['EST'].value_counts(10).iloc[-6:].index,palette='tab10')

# %%
plt.figure(figsize=(14, 10))
ax = sns.countplot(x=data_clean['area_endemism'],order=data_clean['area_endemism'].value_counts().iloc[:10].index,palette='tab10')
plt.title('Specimens by Areas of endemism',fontsize=20)
plt.xlabel('Area of endemism',fontsize=15)
plt.ylabel('Number of Specimens',fontsize=15)

add_perc(ax,data_clean['area_endemism'])

# %%
collect = pd.DataFrame(data_clean['DATA COLETA'].apply(pd.to_datetime,errors='coerce'))

# %%
collect.head()
# Out:
#   DATA COLETA
# 0  2003-09-11
# 1  2003-09-11
# 2  2003-09-11
# 3  2003-09-11
# 4  2003-09-12

# %%
collect = collect[collect['DATA COLETA'].isna() == False]

# %%
collect.head()
# Out:
#   DATA COLETA
# 0  2003-09-11
# 1  2003-09-11
# 2  2003-09-11
# 3  2003-09-11
# 4  2003-09-12

# %%
collect['year'] = pd.DataFrame(collect['DATA COLETA'].apply(lambda x: x.year))
collect
# Out:
#       DATA COLETA  year
# 0      2003-09-11  2003
# 1      2003-09-11  2003
# 2      2003-09-11  2003
# 3      2003-09-11  2003
# 4      2003-09-12  2003
# ...           ...   ...
# 28264  2019-12-17  2019
# 28265  2019-12-17  2019
# 28266  2019-12-17  2019
# 28267  2019-12-17  2019
# 28268  2019-12-17  2019
#
# [26262 rows x 2 columns]

# %%
collect_year = collect.groupby(by='year').count()

# %%
collect_year.rename(columns={'DATA COLETA':'samples'},inplace=True)
collect_year
# Out:
#       samples
# year
# 1996        1
# 1998        1
# 1999        6
# 2000        1
# 2001       14
# 2002       25
# 2003      618
# 2004      300
# 2005      314
# 2006      679
# 2007      657
# 2008      471
# 2009      565
# 2010     1785
# 2011     2437
# 2012     5414
# 2013     5300
# 2014     2005
# 2015      386
# 2016      790
# 2017     1423
# 2018     1043
# 2019     1692
# 2020       22
# 2021      313

# %%
sns.lineplot(data=collect_year,x='year', y = 'samples')
plt.title("Nº of bird genetic samples deposite at INPA's genetic resources collection per year")
plt.ylabel("Genetic samples")
plt.xlabel("Year")
# Out:
# Text(0.5, 0, 'Year')

# %%
collect_year['cumsum'] = collect_year.samples.cumsum()
collect_year.head()
# Out:
#       samples  cumsum
# year
# 1996        1       1
# 1998        1       2
# 1999        6       8
# 2000        1       9
# 2001       14      23

# %%
sns.lineplot(data=collect_year,x='year', y = 'cumsum')
plt.title("Total nº of genetic samples of birds at INPA's genetic resources collection")
plt.xlabel("Year")
plt.ylabel("Genetic samples")
# Out:
# Text(0, 0.5, 'Genetic samples')

# %%
db['EXPEDIÇÃO'].value_counts(ascending=False).head(100)
# Out:
# JSM Doutorado 2012         785
# São Gabriel 2013 MPEG      767
# Sisbiota Japurá 2014       612
# BR 319 PRONEX 2012         611
# LNN Doutorado              533
#                           ...
# 06/06/2017 à 09/06/2017     29
# 08/08/2017 à 12/08/2017     29
# BR 319 2007                 28
# POA_Ago_2015                27
# Tapirapecó 2003             27
# Name: EXPEDIÇÃO, Length: 100, dtype: int64

# %%
#ANOTHER FUNCTION TO ADD PERCENTAGE OVER BAR OR COUNT PLOT
def add_perc(plot, feature):
    total = len(feature)
    for p in ax.patches:
        x=p.get_bbox().get_points()[:,0]
        y=p.get_bbox().get_points()[1,1]
        ax.annotate('{:.1f}%'.format(100.*y/len(sample_type_sexo)), (x.mean(), y), ha='center', va='bottom')

# %%
data_clean['PARA.1'].value_counts()
# Out:
# Alexandre Mendes Fernandes      64
# Marina Anciães                  44
# Luciano Nicolas Naka            37
# Henrique Batalha Filho          10
# Camila Ribas/Mario Cohn-Haft     5
# Carlos Eduardo Agne              2
# Ivã Barbosa Santos               2
# Curtis Marantz                   1
# Name: PARA.1, dtype: int64

# %%
data_clean['PARA.2'].value_counts()
# Out:
# Alexandre Mendes Fernandes    26
# Marina Anciães                 9
# Henrique Batalha Filho         2
# Carlos Eduardo Agne            1
# Luciano Nicolas Naka           1
# Name: PARA.2, dtype: int64

# %%
data_clean['PARA.3'].value_counts()
# Out:
# Alexandre Mendes Fernandes    2
# Name: PARA.3, dtype: int64

# %%
grants = data_clean['PARA.1'].value_counts()+data_clean['PARA.2'].value_counts()+data_clean['PARA.3'].value_counts().sort_values(ascending=False)
grants
# Out:
# Alexandre Mendes Fernandes      92.0
# Camila Ribas/Mario Cohn-Haft     NaN
# Carlos Eduardo Agne              NaN
# Curtis Marantz                   NaN
# Henrique Batalha Filho           NaN
# Ivã Barbosa Santos               NaN
# Luciano Nicolas Naka             NaN
# Marina Anciães                   NaN
# dtype: float64

# %%
data_clean[['PARA.1', 'PARA.2','PARA.3']].apply(pd.Series.value_counts)
# Out:
#                               PARA.1  PARA.2  PARA.3
# Alexandre Mendes Fernandes        64    26.0     2.0
# Camila Ribas/Mario Cohn-Haft       5     NaN     NaN
# Carlos Eduardo Agne                2     1.0     NaN
# Curtis Marantz                     1     NaN     NaN
# Henrique Batalha Filho            10     2.0     NaN
# Ivã Barbosa Santos                 2     NaN     NaN
# Luciano Nicolas Naka              37     1.0     NaN
# Marina Anciães                    44     9.0     NaN

# %%
data_clean[['PARA.1', 'PARA.2','PARA.3']].dropna().melt(var_name='columns', value_name='person')
# Out:
#   columns                      person
# 1  PARA.1        Luciano Nicolas Naka
# 2  PARA.2  Alexandre Mendes Fernandes
# 3  PARA.2  Alexandre Mendes Fernandes
# 4  PARA.3  Alexandre Mendes Fernandes
# 5  PARA.3  Alexandre Mendes Fernandes

# %%
tissue_loans = pd.DataFrame({'samples':data_clean[['PARA','PARA.1', 'PARA.2','PARA.3']].melt(var_name='columns', value_name='person')['person'].value_counts()})
tissue_loans
# Out:
#                               samples
# Luciano Nicolas Naka              708
# Alexandre Mendes Fernandes        351
# Marina Anciães                    150
# Alex Jahn/Waleska Gravena          34
# Claydson P. de Assis               30
# Carla Haisler Sardelli             29
# Henrique Batalha Filho             21
# Camila Ribas                       15
# Alexandre Aleixo                   13
# Izeni Farias                       12
# Cristina Yumi Miyaki                9
# Camila Ribas/Mario Cohn-Haft        9
# Sidnei de Melo Dantas               7
# Nicolas Davila Llamosa              6
# Ivã Barbosa Santos                  4
# Carlos Eduardo Agne                 4
# Carla Suertegaray Fontana           3
# Curtis Marantz                      3

# %%
sum(tissue_loans.samples)
# Out:
# 1408

# %%
plt.figure(figsize=(14,10))
ax = sns.barplot(data=tissue_loans[:5],x=tissue_loans.index[:5], y='samples')
plt.title('Top 5 tissue loans request by person',fontsize=20)
plt.xlabel('Person',fontsize=15)
plt.ylabel('Number of samples',fontsize=15)


add_perc(ax,pd.DataFrame({'samples':data_clean[['PARA','PARA.1', 'PARA.2','PARA.3']].melt(var_name='columns', value_name='person')['person']}).dropna())

# %%
data_clean[['PARA','PARA.1', 'PARA.2','PARA.3']].melt(var_name='columns', value_name='person')['person'].value_counts()
# Out:
# Luciano Nicolas Naka            708
# Alexandre Mendes Fernandes      351
# Marina Anciães                  150
# Alex Jahn/Waleska Gravena        34
# Claydson P. de Assis             30
# Carla Haisler Sardelli           29
# Henrique Batalha Filho           21
# Camila Ribas                     15
# Alexandre Aleixo                 13
# Izeni Farias                     12
# Cristina Yumi Miyaki              9
# Camila Ribas/Mario Cohn-Haft      9
# Sidnei de Melo Dantas             7
# Nicolas Davila Llamosa            6
# Ivã Barbosa Santos                4
# Carlos Eduardo Agne               4
# Carla Suertegaray Fontana         3
# Curtis Marantz                    3
# Name: person, dtype: int64

# %%
data_clean[['PARA','PARA.1', 'PARA.2','PARA.3']].melt(var_name='columns', value_name='person')[['person']]
# Out:
#                       person
# 0                        NaN
# 1                        NaN
# 2       Claydson P. de Assis
# 3                        NaN
# 4                        NaN
# ...                      ...
# 105955                   NaN
# 105956                   NaN
# 105957                   NaN
# 105958                   NaN
# 105959                   NaN
#
# [105960 rows x 1 columns]

# %%
pd.DataFrame({'samples':data_clean[['PARA','DATA','PARA.1','DATA.1', 'PARA.2','DATA.2','PARA.3','DATA.3']].melt(var_name='columns', value_name='person')['person']}).dropna()
# Out:
#                            samples
# 2             Claydson P. de Assis
# 7           Carla Haisler Sardelli
# 8             Luciano Nicolas Naka
# 11            Claydson P. de Assis
# 18            Claydson P. de Assis
# ...                            ...
# 134443                  28/04/2009
# 160051  Alexandre Mendes Fernandes
# 160086  Alexandre Mendes Fernandes
# 186541                  23/10/2009
# 186576                  23/10/2009
#
# [2816 rows x 1 columns]

# %%
data_clean[['GUIA N°','GUIA N°.1','GUIA N°.2','GUIA N°.3','PARA','DATA','PARA.1','DATA.1', 'PARA.2','DATA.2','PARA.3','DATA.3']].melt(id_vars=('GUIA N°','GUIA N°.1','GUIA N°.2','GUIA N°.3'),value_vars=['DATA','DATA.1','DATA.2','DATA.3'])
# Out:
#         GUIA N°  GUIA N°.1  GUIA N°.2  GUIA N°.3 variable       value
# 0           NaN        NaN        NaN        NaN     DATA         NaN
# 1           NaN        NaN        NaN        NaN     DATA         NaN
# 2          59.0        NaN        NaN        NaN     DATA  21/09/2010
# 3           NaN        NaN        NaN        NaN     DATA         NaN
# 4           NaN        NaN        NaN        NaN     DATA         NaN
# ...         ...        ...        ...        ...      ...         ...
# 105955      NaN        NaN        NaN        NaN   DATA.3         NaN
# 105956      NaN        NaN        NaN        NaN   DATA.3         NaN
# 105957      NaN        NaN        NaN        NaN   DATA.3         NaN
# 105958      NaN        NaN        NaN        NaN   DATA.3         NaN
# 105959      NaN        NaN        NaN        NaN   DATA.3         NaN
#
# [105960 rows x 6 columns]

# %%
loans = data_clean[['GUIA N°','PARA','DATA']].dropna().groupby('GUIA N°').first()
loans
# Out:
#                                  PARA        DATA
# GUIA N°
# 3.0            Carla Haisler Sardelli  01/06/2004
# 4.0            Carla Haisler Sardelli  09/09/2004
# 5.0            Carla Haisler Sardelli  05/11/2004
# 7.0        Alexandre Mendes Fernandes  21/07/2005
# 11.0                 Alexandre Aleixo  28/10/2005
# 12.0       Alexandre Mendes Fernandes  09/12/2005
# 16.0                   Marina Anciães  11/08/2006
# 17.0       Alexandre Mendes Fernandes  01/09/2006
# 18.0       Alexandre Mendes Fernandes  16/10/2006
# 19.0                   Marina Anciães  16/10/2006
# 20.0                   Marina Anciães  23/10/2006
# 21.0       Alexandre Mendes Fernandes  20/11/2006
# 22.0       Alexandre Mendes Fernandes  27/11/2006
# 23.0                   Marina Anciães  01/12/2006
# 25.0             Luciano Nicolas Naka  05/03/2007
# 26.0        Alex Jahn/Waleska Gravena  08/05/2007
# 27.0             Cristina Yumi Miyaki  09/05/2007
# 29.0                 Alexandre Aleixo  18/07/2007
# 30.0                   Curtis Marantz  18/07/2007
# 31.0                   Marina Anciães  08/10/2007
# 33.0                   Marina Anciães  07/11/2007
# 34.0             Luciano Nicolas Naka  10/12/2007
# 35.0                   Marina Anciães  29/12/2007
# 36.0       Alexandre Mendes Fernandes  22/04/2008
# 38.0                 Alexandre Aleixo  30/10/2008
# 39.0           Nicolas Davila Llamosa  31/10/2008
# 40.0                     Camila Ribas  17/12/2008
# 41.0             Luciano Nicolas Naka  17/12/2008
# 42.0             Luciano Nicolas Naka  10/03/2009
# 43.0                     Izeni Farias  15/04/2009
# 44.0                   Marina Anciães  28/04/2009
# 45.0                   Marina Anciães  17/06/2009
# 48.0     Camila Ribas/Mario Cohn-Haft  17/07/2009
# 50.0       Alexandre Mendes Fernandes  16/10/2009
# 51.0       Alexandre Mendes Fernandes  19/10/2009
loans_1['number_specimen'] = data_clean[['GUIA N°.1','PARA.1','DATA.1']].dropna().groupby('GUIA N°.1').size()
loans_1.set_axis(['para','data','number_specimens'],axis=1,inplace=True)
loans_1
# Out:
#                                    para        data  number_specimens
# GUIA N°.1
# 25.0               Luciano Nicolas Naka  05/03/2007                18
# 30.0                     Curtis Marantz  18/07/2007                 1
# 31.0                     Marina Anciães  08/10/2007                 1
# 34.0               Luciano Nicolas Naka  10/12/2007                 5
# 35.0                     Marina Anciães  29/12/2007                 1
# 36.0         Alexandre Mendes Fernandes  22/04/2008                30
# 41.0               Luciano Nicolas Naka  17/12/2008                14
# 44.0                     Marina Anciães  28/04/2009                42
# 48.0       Camila Ribas/Mario Cohn-Haft  17/07/2009                 5
# 51.0         Alexandre Mendes Fernandes  19/10/2009                11
# 52.0                 Ivã Barbosa Santos  20/10/2009                 2
# 53.0         Alexandre Mendes Fernandes  23/10/2009                23
# 58.0                Carlos Eduardo Agne  27/05/2010                 2
# 61.0             Henrique Batalha Filho  26/11/2010                10

# %%
loans_2 = data_clean[['GUIA N°.2','PARA.2','DATA.2']].dropna().groupby('GUIA N°.2').first()
loans_2['number_specimen'] = data_clean[['GUIA N°.2','PARA.2','DATA.2']].dropna().groupby('GUIA N°.2').size()
loans_2.set_axis(['para','data','number_specimens'],axis=1,inplace=True)
loans_2
# Out:
#                                  para        data  number_specimens
# GUIA N°.2
# 36.0       Alexandre Mendes Fernandes  22/04/2008                 2
# 41.0             Luciano Nicolas Naka  17/12/2008                 1
# 44.0                   Marina Anciães  28/04/2009                 9
# 51.0       Alexandre Mendes Fernandes  19/10/2009                24
# 58.0              Carlos Eduardo Agne  27/05/2010                 1
# 61.0           Henrique Batalha Filho  26/11/2010                 2

# %%
loans_3 = data_clean[['GUIA N°.3','PARA.3','DATA.3']].dropna().groupby('GUIA N°.3').first()
loans_3['number_specimen'] = data_clean[['GUIA N°.3','PARA.3','DATA.3']].dropna().groupby('GUIA N°.3').size()
loans_3.set_axis(['para','data','number_specimens'],axis=1,inplace=True)
loans_3
# Out:
#                                  para        data  number_specimens
# GUIA N°.3
# 53.0       Alexandre Mendes Fernandes  23/10/2009                 2

# %%
loans_concat = pd.concat([loans,loans_1,loans_2,loans_3])

# %%
loans_concat.head(63)
# Out:
#                             para        data  number_specimens
# 3.0       Carla Haisler Sardelli  01/06/2004                10
# 4.0       Carla Haisler Sardelli  09/09/2004                11
# 5.0       Carla Haisler Sardelli  05/11/2004                 8
# 7.0   Alexandre Mendes Fernandes  21/07/2005                37
# 11.0            Alexandre Aleixo  28/10/2005                 8
# ...                          ...         ...               ...
# 44.0              Marina Anciães  28/04/2009                 9
# 51.0  Alexandre Mendes Fernandes  19/10/2009                24
# 58.0         Carlos Eduardo Agne  27/05/2010                 1
# 61.0      Henrique Batalha Filho  26/11/2010                 2
# 53.0  Alexandre Mendes Fernandes  23/10/2009                 2
#
# [63 rows x 3 columns]

# %%
loans_concat['institution'] = ['Instituto Nacional de Pesquisas da Amazonia','Instituto Nacional de Pesquisas da Amazonia','Instituto Nacional de Pesquisas da Amazonia','Instituto Nacional de Pesquisas da Amazonia','Museu Paraense Emilio Goeldi','Instituto Nacional de Pesquisas da Amazonia','Instituto Nacional de Pesquisas da Amazonia','Instituto Nacional de Pesquisas da Amazonia','Instituto Nacional de Pesquisas da Amazonia','Instituto Nacional de Pesquisas da Amazonia','Instituto Nacional de Pesquisas da Amazonia','Instituto Nacional de Pesquisas da Amazonia','Instituto Nacional de Pesquisas da Amazonia','Instituto Nacional de Pesquisas da Amazonia','
loans_concat
# Out:
#                             para        data  number_specimens  \
# 3.0       Carla Haisler Sardelli  01/06/2004                10
# 4.0       Carla Haisler Sardelli  09/09/2004                11
# 5.0       Carla Haisler Sardelli  05/11/2004                 8
# 7.0   Alexandre Mendes Fernandes  21/07/2005                37
# 11.0            Alexandre Aleixo  28/10/2005                 8
# ...                          ...         ...               ...
# 44.0              Marina Anciães  28/04/2009                 9
# 51.0  Alexandre Mendes Fernandes  19/10/2009                24
# 58.0         Carlos Eduardo Agne  27/05/2010                 1
# 61.0      Henrique Batalha Filho  26/11/2010                 2
# 53.0  Alexandre Mendes Fernandes  23/10/2009                 2
#
#                                             institution      pais
# 3.0         Instituto Nacional de Pesquisas da Amazonia    Brasil
# 4.0         Instituto Nacional de Pesquisas da Amazonia    Brasil
# 5.0         Instituto Nacional de Pesquisas da Amazonia    Brasil
# 7.0         Instituto Nacional de Pesquisas da Amazonia    Brasil
# 11.0                       Museu Paraense Emilio Goeldi    Brasil
# ...                                                 ...       ...
# 44.0        Instituto Nacional de Pesquisas da Amazonia    Brasil
# 51.0                             Universitat Heidelberg  Alemanha
# 58.0  Pontifícia Universidade Católica do Rio Grande...    Brasil
# 61.0                          Universidade de São Paulo    Brasil
# 53.0                             Universitat Heidelberg  Alemanha
#
# [63 rows x 5 columns]

# %%
loans_concat['estado'] = ['Amazonas','Amazonas','Amazonas','Amazonas','Para','Amazonas','Amazonas','Amazonas','Amazonas','Amazonas','Amazonas','Amazonas','Amazonas','Amazonas',np.nan,np.nan,'Sao Paulo','Para',np.nan,'Amazonas','Amazonas',np.nan,'Amazonas',np.nan,'Para',np.nan,'Amazonas',np.nan,np.nan,'Amazonas','Amazonas','Amazonas','Amazonas',np.nan,np.nan,'Para',np.nan,'Rio Grande do Sul','Para','Rio Grande do Sul','Rio de Janeiro','Sao Paulo','Amazonas',np.nan,'Amazonas',np.nan,'Amazonas',np.nan,np.nan,'Amazonas','Amazonas',np.nan,'Para',np.nan,'Rio Grande do Sul','Sao Paulo',np.nan,np.nan,'Amazonas',np.nan,'Rio Grande do Sul','Universidade de Sao Paulo',np.nan]
loans_concat
# Out:
#                             para        data  number_specimens  \
# 3.0       Carla Haisler Sardelli  01/06/2004                10
# 4.0       Carla Haisler Sardelli  09/09/2004                11
# 5.0       Carla Haisler Sardelli  05/11/2004                 8
# 7.0   Alexandre Mendes Fernandes  21/07/2005                37
# 11.0            Alexandre Aleixo  28/10/2005                 8
# ...                          ...         ...               ...
# 44.0              Marina Anciães  28/04/2009                 9
# 51.0  Alexandre Mendes Fernandes  19/10/2009                24
# 58.0         Carlos Eduardo Agne  27/05/2010                 1
# 61.0      Henrique Batalha Filho  26/11/2010                 2
# 53.0  Alexandre Mendes Fernandes  23/10/2009                 2
#
#                                             institution      pais  \
# 3.0         Instituto Nacional de Pesquisas da Amazonia    Brasil
# 4.0         Instituto Nacional de Pesquisas da Amazonia    Brasil
# 5.0         Instituto Nacional de Pesquisas da Amazonia    Brasil
# 7.0         Instituto Nacional de Pesquisas da Amazonia    Brasil
# 11.0                       Museu Paraense Emilio Goeldi    Brasil
# ...                                                 ...       ...
# 44.0        Instituto Nacional de Pesquisas da Amazonia    Brasil
# 51.0                             Universitat Heidelberg  Alemanha
# 58.0  Pontifícia Universidade Católica do Rio Grande...    Brasil
# 61.0                          Universidade de São Paulo    Brasil
# 53.0                             Universitat Heidelberg  Alemanha
#
#                          estado
# 3.0                    Amazonas
# 4.0                    Amazonas
# 5.0                    Amazonas
# 7.0                    Amazonas
# 11.0                       Para
# ...                         ...
# 44.0                   Amazonas
# 51.0                        NaN
# 58.0          Rio Grande do Sul
# 61.0  Universidade de Sao Paulo
# 53.0                        NaN
#
# [63 rows x 6 columns]

# %%
loans_imported = pd.read_csv('./database/cgr_inpa_loans.csv',sep=';')
loans_imported
# Out:
#     Número da Remessa Coleção Destinatário Responsável  \
# 0                  T1    Aves           Sabryna Taylor
# 1                  T2    Aves      Robert E. Ricklefs
# 2                  T3    Aves         Alexandre Aleixo
# 3                  T4    Aves         Alexandre Aleixo
# 4                  T5    Aves         Alexandre Aleixo
# ..                ...     ...                      ...
# 993               NaN     NaN                      NaN
# 994               NaN     NaN                      NaN
# 995               NaN     NaN                      NaN
# 996               NaN     NaN                      NaN
# 997               NaN     NaN                      NaN
#
#                                            Solicitante  \
# 0                                          Jared Wolfe
# 1                                       Letícia Soares
# 2    José Julian Rodríguez Quitiaquez – A/C Cinthia...
# 3                                        Bruno Almeida
# 4                                     Antonita Santana
# ..                                                 ...
# 993                                                NaN
# 994                                                NaN
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
#
#                                 Instituição de destino  \
# 0    School of Renewable Natural Resources/Louisian...
# 1    Department of Biology/University of Missouri-S...
# 2    Museu Paraense Emílio Goeldi, Campus de Pesqui...
# 3    Museu Paraense Emílio Goeldi, Campus de Pesqui...
# 4    Museu Paraense Emílio Goeldi, Campus de Pesqui...
# ..                                                 ...
# 993                                                NaN
# 994                                                NaN
# 995                                                NaN
# 996                                                NaN
# 997                                                NaN
#
#        Instituicao_do_solicitante            Pais Estado Data do empréstimo  \
# 0      Louisiana State University  Estados Unidos    NaN         27/09/2011
# 1          University of Missouri  Estados Unidos    NaN         18/10/2011
# 2    Museu Paraense Emílio Goeldi          Brasil   Para         01/12/2011
# 3    Museu Paraense Emílio Goeldi          Brasil   Para         20/03/2012
# 4    Museu Paraense Emílio Goeldi          Brasil   Para         28/05/2012
# ..                            ...             ...    ...                ...
# 993                           NaN             NaN    NaN                NaN
# 994                           NaN             NaN    NaN                NaN
# 995                           NaN             NaN    NaN                NaN
# 996                           NaN             NaN    NaN                NaN
# 997                           NaN             NaN    NaN                NaN
#
#     Prazo de empréstimo Foma de entrega do material  Número de Espécimes  \
# 0                 1 ano                     Correio                788.0
# 1                 1 ano                     Correio                256.0
# 2                 1 ano                     Correio                 72.0
# 3                 1 ano                     Correio                  2.0
# 4                 1 ano                     Correio                 55.0
# ..                  ...                         ...                  ...
# 993                 NaN                         NaN                  NaN
# 994                 NaN                         NaN                  NaN
# 995                 NaN                         NaN                  NaN
# 996                 NaN                         NaN                  NaN
# 997                 NaN                         NaN                  NaN
#
#     Método de preservação Natureza do envio   Conferido por
# 0                  buffer        empréstimo  Marlene Freitas
# 1                  buffer        empréstimo  Marlene Freitas
# 2                  buffer        empréstimo  Marlene Freitas
# 3                  buffer        empréstimo  Marlene Freitas
# 4                  buffer        empréstimo  Marlene Freitas
# ..                    ...               ...              ...
# 993                   NaN               NaN              NaN
# 994                   NaN               NaN              NaN
# 995                   NaN               NaN              NaN
# 996                   NaN               NaN              NaN
# 997                   NaN               NaN              NaN
#
# [998 rows x 15 columns]

# %%
loans_imported = loans_imported[loans_imported['Coleção'] == 'Aves'][['Número da Remessa','Solicitante','Instituicao_do_solicitante','Pais', 'Estado','Data do empréstimo','Número de Espécimes']]
loans_imported
# Out:
#     Número da Remessa                                        Solicitante  \
# 0                  T1                                        Jared Wolfe
# 1                  T2                                     Letícia Soares
# 2                  T3  José Julian Rodríguez Quitiaquez – A/C Cinthia...
# 3                  T4                                      Bruno Almeida
# 4                  T5                                   Antonita Santana
# ..                ...                                                ...
# 179              T144                                    Glaucia Del Rio
# 207              T161                                    Andre Moncrieff
# 208              T162                                    Eduardo Schultz
# 209              T162                                    Eduardo Schultz
# 212              T164                                       Luciano Naka
#
#                             Instituicao_do_solicitante            Pais  \
# 0                           Louisiana State University  Estados Unidos
# 1                               University of Missouri  Estados Unidos
# 2                         Museu Paraense Emílio Goeldi          Brasil
# 3                         Museu Paraense Emílio Goeldi          Brasil
# 4                         Museu Paraense Emílio Goeldi          Brasil
# ..                                                 ...             ...
# 179                          Universidade de São Paulo          Brasil
# 207  Louisiana State University, Museum of Natural ...  Estados Unidos
# 208        Instituto Nacional de Pesquisas da Amazônia          Brasil
# 209        Instituto Nacional de Pesquisas da Amazônia          Brasil
# 212                 Universidade Federal de Pernambuco          Brasil
#
#          Estado Data do empréstimo  Número de Espécimes
# 0           NaN         27/09/2011                788.0
# 1           NaN         18/10/2011                256.0
# 2          Para         01/12/2011                 72.0
# 3          Para         20/03/2012                  2.0
# 4          Para         28/05/2012                 55.0
# ..          ...                ...                  ...
# 179   Sao Paulo         21/01/2019                 21.0
# 207         NaN         16/10/2019                  6.0
# 208    Amazonas         21/12/2019                 13.0
# 209    Amazonas         21/12/2019                 13.0
# 212  Pernambuco         11/11/2019                  1.0
#
# [105 rows x 7 columns]

# %%
loans_imported.set_index('Número da Remessa',inplace=True)
loans_imported.rename(columns={'Solicitante':'para','Instituicao_do_solicitante':'institution','Pais':'pais','Estado':'estado','Número de Espécimes':'number_specimens','Data do empréstimo':'data'},inplace=True)
loans_imported
# Out:
#                                                                 para  \
# Número da Remessa
# T1                                                       Jared Wolfe
# T2                                                    Letícia Soares
# T3                 José Julian Rodríguez Quitiaquez – A/C Cinthia...
# T4                                                     Bruno Almeida
# T5                                                  Antonita Santana
# ...                                                              ...
# T144                                                 Glaucia Del Rio
# T161                                                 Andre Moncrieff
# T162                                                 Eduardo Schultz
# T162                                                 Eduardo Schultz
# T164                                                    Luciano Naka
#
#                                                          institution  \
# Número da Remessa
# T1                                        Louisiana State University
# T2                                            University of Missouri
# T3                                      Museu Paraense Emílio Goeldi
# T4                                      Museu Paraense Emílio Goeldi
# T5                                      Museu Paraense Emílio Goeldi
# ...                                                              ...
# T144                                       Universidade de São Paulo
# T161               Louisiana State University, Museum of Natural ...
# T162                     Instituto Nacional de Pesquisas da Amazônia
# T162                     Instituto Nacional de Pesquisas da Amazônia
# T164                              Universidade Federal de Pernambuco
#
#                              pais      estado        data  number_specimens
# Número da Remessa
# T1                 Estados Unidos         NaN  27/09/2011             788.0
# T2                 Estados Unidos         NaN  18/10/2011             256.0
# T3                         Brasil        Para  01/12/2011              72.0
# T4                         Brasil        Para  20/03/2012               2.0
# T5                         Brasil        Para  28/05/2012              55.0
# ...                           ...         ...         ...               ...
# T144                       Brasil   Sao Paulo  21/01/2019              21.0
# T161               Estados Unidos         NaN  16/10/2019               6.0
# T162                       Brasil    Amazonas  21/12/2019              13.0
# T162                       Brasil    Amazonas  21/12/2019              13.0
# T164                       Brasil  Pernambuco  11/11/2019               1.0
#
# [105 rows x 6 columns]

# %%
loans = pd.concat([loans_concat,loans_imported])
loans
# Out:
#                             para        data  number_specimens  \
# 3.0       Carla Haisler Sardelli  01/06/2004              10.0
# 4.0       Carla Haisler Sardelli  09/09/2004              11.0
# 5.0       Carla Haisler Sardelli  05/11/2004               8.0
# 7.0   Alexandre Mendes Fernandes  21/07/2005              37.0
# 11.0            Alexandre Aleixo  28/10/2005               8.0
# ...                          ...         ...               ...
# T144             Glaucia Del Rio  21/01/2019              21.0
# T161             Andre Moncrieff  16/10/2019               6.0
# T162             Eduardo Schultz  21/12/2019              13.0
# T162             Eduardo Schultz  21/12/2019              13.0
# T164                Luciano Naka  11/11/2019               1.0
#
#                                             institution            pais  \
# 3.0         Instituto Nacional de Pesquisas da Amazonia          Brasil
# 4.0         Instituto Nacional de Pesquisas da Amazonia          Brasil
# 5.0         Instituto Nacional de Pesquisas da Amazonia          Brasil
# 7.0         Instituto Nacional de Pesquisas da Amazonia          Brasil
# 11.0                       Museu Paraense Emilio Goeldi          Brasil
# ...                                                 ...             ...
# T144                          Universidade de São Paulo          Brasil
# T161  Louisiana State University, Museum of Natural ...  Estados Unidos
# T162        Instituto Nacional de Pesquisas da Amazônia          Brasil
# T162        Instituto Nacional de Pesquisas da Amazônia          Brasil
# T164                 Universidade Federal de Pernambuco          Brasil
#
#           estado
# 3.0     Amazonas
# 4.0     Amazonas
# 5.0     Amazonas
# 7.0     Amazonas
# 11.0        Para
# ...          ...
# T144   Sao Paulo
# T161         NaN
# T162    Amazonas
# T162    Amazonas
# T164  Pernambuco
#
# [168 rows x 6 columns]

# %%
loans['data'] = pd.DataFrame(loans['data'].apply(pd.to_datetime,errors='coerce'))

# %%
loans['year'] = pd.DataFrame(loans['data'].apply(lambda x: x.year))
loans
# Out:
#                             para       data  number_specimens  \
# 3.0       Carla Haisler Sardelli 2004-01-06              10.0
# 4.0       Carla Haisler Sardelli 2004-09-09              11.0
# 5.0       Carla Haisler Sardelli 2004-05-11               8.0
# 7.0   Alexandre Mendes Fernandes 2005-07-21              37.0
# 11.0            Alexandre Aleixo 2005-10-28               8.0
# ...                          ...        ...               ...
# T144             Glaucia Del Rio 2019-01-21              21.0
# T161             Andre Moncrieff 2019-10-16               6.0
# T162             Eduardo Schultz 2019-12-21              13.0
# T162             Eduardo Schultz 2019-12-21              13.0
# T164                Luciano Naka 2019-11-11               1.0
#
#                                             institution            pais  \
# 3.0         Instituto Nacional de Pesquisas da Amazonia          Brasil
# 4.0         Instituto Nacional de Pesquisas da Amazonia          Brasil
# 5.0         Instituto Nacional de Pesquisas da Amazonia          Brasil
# 7.0         Instituto Nacional de Pesquisas da Amazonia          Brasil
# 11.0                       Museu Paraense Emilio Goeldi          Brasil
# ...                                                 ...             ...
# T144                          Universidade de São Paulo          Brasil
# T161  Louisiana State University, Museum of Natural ...  Estados Unidos
# T162        Instituto Nacional de Pesquisas da Amazônia          Brasil
# T162        Instituto Nacional de Pesquisas da Amazônia          Brasil
# T164                 Universidade Federal de Pernambuco          Brasil
#
#           estado  year
# 3.0     Amazonas  2004
# 4.0     Amazonas  2004
# 5.0     Amazonas  2004
# 7.0     Amazonas  2005
# 11.0        Para  2005
# ...          ...   ...
# T144   Sao Paulo  2019
# T161         NaN  2019
# T162    Amazonas  2019
# T162    Amazonas  2019
# T164  Pernambuco  2019
#
# [168 rows x 7 columns]

# %%
plt.figure(figsize=(14,10))
ax = sns.barplot(y=loans.groupby('para').sum()['number_specimens'].sort_values(ascending=False)[:6],x=loans.groupby('para').sum()['number_specimens'].sort_values(ascending=False).index[:6])
plt.title('Top 6 tissue loans request by person',fontsize=20)
plt.xlabel('Person',fontsize=15)
plt.ylabel('Number of samples',fontsize=15)

for p in ax.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    ax.annotate('{:.1f}%'.format(100.*y/loans['number_specimens'].sum()), (x.mean(), y), ha='center', va='bottom')

# %%
plt.figure(figsize=(14,10))
ax = sns.barplot(y=loans.groupby('pais').sum()['number_specimens'].sort_values(ascending=False)[:6],x=loans.groupby('pais').sum()['number_specimens'].sort_values(ascending=False).index[:6])
plt.title('Top 6 tissue loan requests by country',fontsize=20)
plt.xlabel('country',fontsize=15)
plt.ylabel('Number of samples',fontsize=15)

for p in ax.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    ax.annotate('{:.1f}%'.format(100.*y/loans['number_specimens'].sum()), (x.mean(), y), ha='center', va='bottom')

# %%
plt.figure(figsize=(14,10))
ax = sns.barplot(y=loans.groupby('estado').sum()['number_specimens'].sort_values(ascending=False)[:6],x=loans.groupby('estado').sum()['number_specimens'].sort_values(ascending=False).index[:6])
plt.title('Top 6 tissue loan request by Brazilian States',fontsize=20)
plt.xlabel('State',fontsize=15)
plt.ylabel('Number of samples',fontsize=15)

for p in ax.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    ax.annotate('{:.1f}%'.format(100.*y/loans['number_specimens'].sum()), (x.mean(), y), ha='center', va='bottom')

# %%
plt.figure(figsize=(22,15))
ax = sns.barplot(y=loans.groupby('institution').sum()['number_specimens'].sort_values(ascending=False)[:6],x=loans.groupby('institution').sum()['number_specimens'].sort_values(ascending=False).index[:6])
plt.title('Top 6 tissue loans request by Institution',fontsize=20)
plt.xlabel('Institution',fontsize=15)
plt.ylabel('Number of samples',fontsize=15)

for p in ax.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    ax.annotate('{:.1f}%'.format(100.*y/loans['number_specimens'].sum()), (x.mean(), y), ha='center', va='bottom')

# %%
loans.groupby(by='year').sum().cumsum()
# collect_year.samples.cumsum()
# Out:
# Int64Index([2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014,
#             2015, 2016, 2017, 2018, 2019],
#            dtype='int64', name='year')

# %%
sns.lineplot(x=loans.groupby(by='year').sum().cumsum().index, y = loans.groupby(by='year').sum().cumsum()['number_specimens'])
plt.title("Numbers of genetic samples granted through time")
plt.xlabel("Year")
plt.ylabel("Genetic samples")
# Out:
# Text(0, 0.5, 'Genetic samples')

# %%
loans.groupby('year').sum().cumsum()['number_specimens'].plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
# Out:
# <AxesSubplot:xlabel='year', ylabel='pais'>

# %%
loans
# Out:
#                                                    para       data  \
# 3.0                              Carla Haisler Sardelli 2004-01-06
# 4.0                              Carla Haisler Sardelli 2004-09-09
# 5.0                              Carla Haisler Sardelli 2004-05-11
# 7.0                          Alexandre Mendes Fernandes 2005-07-21
# 11.0                                   Alexandre Aleixo 2005-10-28
# 12.0                         Alexandre Mendes Fernandes 2005-09-12
# 16.0                                     Marina Anciães 2006-11-08
# 17.0                         Alexandre Mendes Fernandes 2006-01-09
# 18.0                         Alexandre Mendes Fernandes 2006-10-16
# 19.0                                     Marina Anciães 2006-10-16
# 20.0                                     Marina Anciães 2006-10-23
# 21.0                         Alexandre Mendes Fernandes 2006-11-20
# 22.0                         Alexandre Mendes Fernandes 2006-11-27
# 23.0                                     Marina Anciães 2006-01-12
# 25.0                               Luciano Nicolas Naka 2007-05-03
# 26.0                          Alex Jahn/Waleska Gravena 2007-08-05
# 27.0                               Cristina Yumi Miyaki 2007-09-05
# 29.0                                   Alexandre Aleixo 2007-07-18
# 30.0                                     Curtis Marantz 2007-07-18
# 31.0                                     Marina Anciães 2007-08-10
# 33.0                                     Marina Anciães 2007-07-11
# 34.0                               Luciano Nicolas Naka 2007-10-12
# 35.0                                     Marina Anciães 2007-12-29
# 36.0                         Alexandre Mendes Fernandes 2008-04-22
# 38.0                                   Alexandre Aleixo 2008-10-30
# 39.0                             Nicolas Davila Llamosa 2008-10-31
# 40.0                                       Camila Ribas 2008-12-17
# 41.0                               Luciano Nicolas Naka 2008-12-17
# 42.0                               Luciano Nicolas Naka 2009-10-03
# 43.0                                       Izeni Farias 2009-04-15
# 44.0                                     Marina Anciães 2009-04-28
# 45.0                                     Marina Anciães 2009-06-17
# 48.0                       Camila Ribas/Mario Cohn-Haft 2009-07-17
# 50.0                         Alexandre Mendes Fernandes 2009-10-16
# 51.0                         Alexandre Mendes Fernandes 2009-10-19
# 52.0                                 Ivã Barbosa Santos 2009-10-20
# 53.0                         Alexandre Mendes Fernandes 2009-10-23
# 56.0                          Carla Suertegaray Fontana 2010-04-13
# 57.0                              Sidnei de Melo Dantas 2010-04-19
# 58.0                                Carlos Eduardo Agne 2010-05-27
# 59.0                               Claydson P. de Assis 2010-09-21
# T31           Brasil                   Amazonas  2014
# T31           Brasil                   Amazonas  2014
# T32   Estados Unidos                        NaN  2014
# T33           Brasil                   Amazonas  2014
# T34           Brasil                 Pernambuco  2014
# T37           Brasil                       Para  2014
# T38           Brasil                  Sao Paulo  2014
# T39         Alemanha                        NaN  2015
# T39         Alemanha                        NaN  2015
# T40   Estados Unidos                        NaN  2015
# T40   Estados Unidos                        NaN  2015
# T42           Brasil                   Amazonas  2015
# T43           Brasil                   Amazonas  2015
# T44           Brasil             Rio de Janeiro  2015
# T45   Estados Unidos                        NaN  2015
# T47           Canada                        NaN  2015
# T48           Brasil                  Sao Paulo  2015
# T49   Estados Unidos                        NaN  2015
# T50   Estados Unidos                        NaN  2015
# T51           Canada                        NaN  2015
# T52        Argentina                        NaN  2015
# T53   Estados Unidos                        NaN  2015
# T54   Estados Unidos                        NaN  2015
# T55           Suecia                        NaN  2015
# T56           Suecia                        NaN  2015
# T57           Suecia                        NaN  2015
# T58           Suecia                        NaN  2015
# T59           Brasil                  Sao Paulo  2015
# T64           Brasil                 Pernambuco  2015
# T65           Brasil                 Pernambuco  2015
# T71   Estados Unidos                        NaN  2015
# T75   Estados Unidos                        NaN  2016
# T75           Brasil                   Amazonas  2016
# T75           Brasil                   Amazonas  2016
# T78           Brasil                   Amazonas  2016
# T79   Estados Unidos                        NaN  2016
# T80   Estados Unidos                        NaN  2016
# T81           Brasil                   Amazonas  2016
# T82           Brasil                   Amazonas  2016
# T82           Brasil                   Amazonas  2016
# T83           Brasil                       Para  2016
# T85           Brasil                       Para  2016
# T87           Brasil                Mins Gerias  2016
# T90           Brasil                   Amazonas  2016
# T92           Brasil                       Para  2017
# T93           Brasil                       Para  2017
# T96           Brasil                       Para  2017
# T97           Brasil                  Sao Paulo  2017
# T99           Brasil                   Amazonas  2017
# T100          Brasil                       Para  2017
# T105          Brasil                  Sao Paulo  2017
# T107          Brasil                   Amazonas  2017
# T107          Brasil                   Amazonas  2017
# T108          Brasil                   Amazonas  2017
# T108          Brasil                   Amazonas  2017
# T109  Estados Unidos                        NaN  2017
# T113          Brasil                        NaN  2018
# T119          Brasil                       Para  2018
# T122          Brasil                      Bahia  2018
# T122          Brasil                      Bahia  2018
# T125          Brasil                       Para  2018
# T131          Brasil                Mato Grosso  2018
# T131          Brasil                Mato Grosso  2018
# T132  Estados Unidos                        NaN  2018
# T132  Estados Unidos                        NaN  2018
# T133          Brasil                   Amazonas  2018
# T133          Brasil                   Amazonas  2018
# T136          Brasil                   Amazonas  2018
# T137  Estados Unidos                        NaN  2018
# T144          Brasil                  Sao Paulo  2019
# T144          Brasil                  Sao Paulo  2019
# T161  Estados Unidos                        NaN  2019
# T162          Brasil                   Amazonas  2019
# T162          Brasil                   Amazonas  2019
# T164          Brasil                 Pernambuco  2019

# %%
loans['month'] = pd.DataFrame(loans['data'].apply(lambda x: x.month))

# %%
sns.heatmap(loans.pivot_table(values='number_specimens',index='year',columns='month'),cmap='viridis')
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>
